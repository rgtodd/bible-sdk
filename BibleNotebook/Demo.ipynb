# %% [markdown]
# # Demo Notebook
#
# ## Data Frame

# %%
import pandas as pd
import numpy as np
from pprint import pprint

print("===== df")
df = pd.read_csv(
    "../BibleCore/Resources/MorphGnt/61-Mt-morphgnt.txt",
    names=[
        "ScriptureReference",
        "PartOfSpeech",
        "Inflection",
        "Text",
        "Word",
        "NormalizedWord",
        "Lemma",
    ],
    dtype={
        "ScriptureReference": "str"
    },
    sep="\\s+",
    index_col=False,
)
print(df.__class__.__name__)
pprint(vars(df))

print("===== col_lemma")
col_lemma = df['Lemma'] 
print(col_lemma.__class__.__name__)
print('-----')
pprint(vars(col_lemma))
print('-----')
pprint(col_lemma)

print("===== col_lemma_boolean")
col_lemma_boolean = col_lemma == 'Χριστός'
print(col_lemma_boolean.__class__.__name__)
print('-----')
pprint(vars(col_lemma_boolean))
print('-----')
pprint(col_lemma_boolean)

print("===== rows")
rows = df.loc[col_lemma_boolean]
print(rows.__class__.__name__)
print('-----')
pprint(vars(rows))
print('-----')
pprint(rows)
# Out:
# ===== df
# DataFrame
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': BlockManager
# Items: Index(['ScriptureReference', 'PartOfSpeech', 'Inflection', 'Text', 'Word',
#        'NormalizedWord', 'Lemma'],
#       dtype='object')
# Axis 1: RangeIndex(start=0, stop=18329, step=1)
# NumpyBlock: slice(0, 7, 1), 7 x 18329, dtype: object}
# ===== col_lemma
# Series
# -----
# {'_attrs': {},
#  '_cacher': ('Lemma',
#              <weakref at 0x00000221D07A7D30; to 'pandas.core.frame.DataFrame' at 0x00000221D048C9D0>),
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': SingleBlockManager
# Items: RangeIndex(start=0, stop=18329, step=1)
# NumpyBlock: 18329 dtype: object,
#  '_name': 'Lemma'}
# -----
# 0           βίβλος
# 1          γένεσις
# 2           Ἰησοῦς
# 3          Χριστός
# 4             υἱός
#            ...
# 18324          ἕως
# 18325            ὁ
# 18326    συντέλεια
# 18327            ὁ
# 18328         αἰών
# Name: Lemma, Length: 18329, dtype: object
# ===== col_lemma_boolean
# Series
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': SingleBlockManager
# Items: RangeIndex(start=0, stop=18329, step=1)
# NumpyBlock: 18329 dtype: bool,
#  '_name': 'Lemma'}
# -----
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 18324    False
# 18325    False
# 18326    False
# 18327    False
# 18328    False
# Name: Lemma, Length: 18329, dtype: bool
# ===== rows
# DataFrame
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': <weakref at 0x00000221D07A7D30; to 'pandas.core.frame.DataFrame' at 0x00000221D048C9D0>,
#  '_item_cache': {},
#  '_mgr': BlockManager
# Items: Index(['ScriptureReference', 'PartOfSpeech', 'Inflection', 'Text', 'Word',
#        'NormalizedWord', 'Lemma'],
#       dtype='object')
# Axis 1: Index([    3,   245,   272,   278,   501,  5618,  9468,  9566, 13458, 13670,
#        14271, 14512, 16795, 16872, 17239, 17319],
#       dtype='int64')
# NumpyBlock: slice(0, 7, 1), 7 x 16, dtype: object}
# -----
#       ScriptureReference PartOfSpeech Inflection      Text     Word  \
# 3                 010101           N-   ----GSM-   χριστοῦ  χριστοῦ
# 245               010116           N-   ----NSM-  χριστός.  χριστός
# 272               010117           N-   ----GSM-   χριστοῦ  χριστοῦ
# 278               010118           N-   ----GSM-   χριστοῦ  χριστοῦ
# 501               010204           N-   ----NSM-   χριστὸς  χριστὸς
# 5618              011102           N-   ----GSM-   χριστοῦ  χριστοῦ
# 9468              011616           N-   ----NSM-   χριστὸς  χριστὸς
# 9566              011620           N-   ----NSM-  χριστός.  χριστός
# 13458             012242           N-   ----GSM-  χριστοῦ;  χριστοῦ
# 13670             012310           N-   ----NSM-  χριστός·  χριστός
# 14271             012405           N-   ----NSM-  χριστός,  χριστός
# 14512             012423           N-   ----NSM-  χριστός,  χριστός
# 16795             012663           N-   ----NSM-   χριστὸς  χριστὸς
# 16872             012668           N-   ----VSM-   χριστέ,   χριστέ
# 17239             012717           N-   ----ASM-  χριστόν;  χριστόν
# 17319             012722           N-   ----ASM-  χριστόν;  χριστόν
#
#       NormalizedWord    Lemma
# 3            Χριστοῦ  Χριστός
# 245          Χριστός  Χριστός
# 272          Χριστοῦ  Χριστός
# 278          Χριστοῦ  Χριστός
# 501          Χριστός  Χριστός
# 5618         Χριστοῦ  Χριστός
# 9468         Χριστός  Χριστός
# 9566         Χριστός  Χριστός
# 13458        Χριστοῦ  Χριστός
# 13670        Χριστός  Χριστός
# 14271        Χριστός  Χριστός
# 14512        Χριστός  Χριστός
# 16795        Χριστός  Χριστός
# 16872         Χριστέ  Χριστός
# 17239        Χριστόν  Χριστός
# 17319        Χριστόν  Χριστός

# %% [markdown]
# ## Grouping

# %%
print('===== df_sorted = df.sort_values("PartOfSpeech")')
df_sorted = df.sort_values("PartOfSpeech")
print(df_sorted.__class__.__name__)
print('-----')
pprint(vars(df_sorted))
print('-----')
pprint(df_sorted)

print('===== gb_lemma = df.groupby("Lemma")')
gb_lemma = df.groupby("Lemma")
print(gb_lemma.__class__.__name__)
print('-----')
pprint(vars(gb_lemma))
print('-----')
pprint(gb_lemma)

print('===== gb_lemma_count = gb_lemma.count()')
gb_lemma_count = gb_lemma.count()
print(gb_lemma_count.__class__.__name__)
print('-----')
pprint(vars(gb_lemma_count))
print('-----')
pprint(gb_lemma_count)

print("===== gb_lemma_partofspeech = gb_lemma['PartOfSpeech']")
gb_lemma_partofspeech = gb_lemma['PartOfSpeech']
print(gb_lemma_partofspeech.__class__.__name__)
print('-----')
pprint(vars(gb_lemma_partofspeech))
print('-----')
pprint(gb_lemma_partofspeech)

print('===== gb_lemma_partofspeech_count = gb_lemma_partofspeech.count()')
gb_lemma_partofspeech_count = gb_lemma_partofspeech.count()
print(gb_lemma_partofspeech_count.__class__.__name__)
print('-----')
pprint(vars(gb_lemma_partofspeech_count))
print('-----')
pprint(gb_lemma_partofspeech_count)

print('===== gb_lemma_partofspeech_count_sum = gb_lemma_partofspeech_count.sum()')
gb_lemma_partofspeech_count_sum = gb_lemma_partofspeech_count.sum()
print(gb_lemma_partofspeech_count_sum.__class__.__name__)
print('-----')
pprint(gb_lemma_partofspeech_count_sum)

print('===== gb_lemma_partofspeech_pct = gb_lemma_partofspeech_count.apply(lambda i: i / gb_lemma_partofspeech_count_sum)')
gb_lemma_partofspeech_pct = gb_lemma_partofspeech_count.apply(lambda i: (i / gb_lemma_partofspeech_count_sum) * 100.0)
gb_lemma_partofspeech_pct = gb_lemma_partofspeech_pct[gb_lemma_partofspeech_pct > 0.5]
gb_lemma_partofspeech_pct = gb_lemma_partofspeech_pct.sort_index()
print(gb_lemma_partofspeech_pct.__class__.__name__)
print('-----')
pprint(vars(gb_lemma_partofspeech_pct))
print('-----')
pprint(gb_lemma_partofspeech_pct)
print('-----')
pprint(gb_lemma_partofspeech_pct.sum())
# Out:
# ===== df_sorted = df.sort_values("PartOfSpeech")
# DataFrame
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': BlockManager
# Items: Index(['ScriptureReference', 'PartOfSpeech', 'Inflection', 'Text', 'Word',
#        'NormalizedWord', 'Lemma'],
#       dtype='object')
# Axis 1: Index([ 6567,  7819, 14231,  2233, 14243,  5824, 14260, 14273,  2210,  7796,
#        ...
#         6917,  7460,  6030,  2437, 12281, 10037, 14549, 15156,  8995, 14865],
#       dtype='int64', length=18329)
# NumpyBlock: slice(0, 7, 1), 7 x 18329, dtype: object}
# -----
#       ScriptureReference PartOfSpeech Inflection       Text      Word  \
# 6567              011231           A-   ----NSF-       πᾶσα      πᾶσα
# 7819              011344           A-   ----APN-      πάντα     πάντα
# 14231             012403           A-   ----ASF-      ἰδίαν     ἰδίαν
# 2233              010533           A-   ----DPM-  ἀρχαίοις·  ἀρχαίοις
# 14243             012403           A-   ----GSF-        σῆς       σῆς
# ...                  ...          ...        ...        ...       ...
# 10037             011717           X-   --------          Ὦ         Ὦ
# 14549             012426           X-   --------       Ἰδοὺ      Ἰδοὺ
# 15156             012512           X-   --------       Ἀμὴν      Ἀμὴν
# 8995              011527           X-   --------       Ναί,       Ναί
# 14865             012443           X-   --------         ἂν        ἂν
#
#       NormalizedWord    Lemma
# 6567            πᾶσα      πᾶς
# 7819           πάντα      πᾶς
# 14231          ἰδίαν    ἴδιος
# 2233        ἀρχαίοις  ἀρχαῖος
# 14243            σῆς      σός
# ...              ...      ...
# 10037              ὦ        ὦ
# 14549           ἰδού     ἰδού
# 15156           ἀμήν     ἀμήν
# 8995             ναί      ναί
# 14865             ἄν       ἄν
#
# [18329 rows x 7 columns]
# ===== gb_lemma = df.groupby("Lemma")
# DataFrameGroupBy
# -----
# {'_grouper': <pandas.core.groupby.ops.BaseGrouper object at 0x00000221D0C51D90>,
#  '_selection': None,
#  'as_index': True,
#  'axis': 0,
#  'dropna': True,
#  'exclusions': frozenset({'Lemma'}),
#  'group_keys': True,
#  'keys': 'Lemma',
#  'level': None,
#  'obj':       ScriptureReference PartOfSpeech Inflection        Text        Word  \
# 0                 010101           N-   ----NSF-      Βίβλος      Βίβλος
# 1                 010101           N-   ----GSF-    γενέσεως    γενέσεως
# 2                 010101           N-   ----GSM-       Ἰησοῦ       Ἰησοῦ
# 3                 010101           N-   ----GSM-     χριστοῦ     χριστοῦ
# 4                 010101           N-   ----GSM-        υἱοῦ        υἱοῦ
# ...                  ...          ...        ...         ...         ...
# 18324             012820           P-   --------         ἕως         ἕως
# 18325             012820           RA   ----GSF-         τῆς         τῆς
# 18326             012820           N-   ----GSF-  συντελείας  συντελείας
# 18327             012820           RA   ----GSM-         τοῦ         τοῦ
# 18328             012820           N-   ----GSM-    ⸀αἰῶνος.      αἰῶνος
#
#       NormalizedWord      Lemma
# 0             βίβλος     βίβλος
# 1           γενέσεως    γένεσις
# 2              Ἰησοῦ     Ἰησοῦς
# 3            Χριστοῦ    Χριστός
# 4               υἱοῦ       υἱός
# ...              ...        ...
# 18324            ἕως        ἕως
# 18325            τῆς          ὁ
# 18326     συντελείας  συντέλεια
# 18327            τοῦ          ὁ
# 18328         αἰῶνος       αἰών
#
# [18329 rows x 7 columns],
#  'observed': False,
#  'sort': True}
# -----
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000221D0C51CC0>
# ===== gb_lemma_count = gb_lemma.count()
# DataFrame
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': BlockManager
# Items: Index(['ScriptureReference', 'PartOfSpeech', 'Inflection', 'Text', 'Word',
#        'NormalizedWord'],
#       dtype='object')
# Axis 1: Index(['Αἴγυπτος', 'Βαβυλών', 'Βαραββᾶς', 'Βαραχίας', 'Βαρθολομαῖος',
#        'Βαριωνᾶ', 'Βεελζεβούλ', 'Βηθανία', 'Βηθλέεμ', 'Βηθσαϊδά',
#        ...
#        'ῥαπίζω', 'ῥαφίς', 'ῥύμη', 'ῥύομαι', 'ῥῆμα', 'Ῥαμά', 'Ῥαχάβ', 'Ῥαχήλ',
#        'Ῥοβοάμ', 'Ῥούθ'],
#       dtype='object', name='Lemma', length=1680)
# NumpyBlock: slice(0, 1, 1), 1 x 1680, dtype: int64
# NumpyBlock: slice(1, 2, 1), 1 x 1680, dtype: int64
# NumpyBlock: slice(2, 3, 1), 1 x 1680, dtype: int64
# NumpyBlock: slice(3, 4, 1), 1 x 1680, dtype: int64
# NumpyBlock: slice(4, 5, 1), 1 x 1680, dtype: int64
# NumpyBlock: slice(5, 6, 1), 1 x 1680, dtype: int64}
# -----
#               ScriptureReference  PartOfSpeech  Inflection  Text  Word  \
# Lemma
# Αἴγυπτος                       4             4           4     4     4
# Βαβυλών                        4             4           4     4     4
# Βαραββᾶς                       5             5           5     5     5
# Βαραχίας                       1             1           1     1     1
# Βαρθολομαῖος                   1             1           1     1     1
# ...                          ...           ...         ...   ...   ...
# Ῥαμά                           1             1           1     1     1
# Ῥαχάβ                          1             1           1     1     1
# Ῥαχήλ                          1             1           1     1     1
# Ῥοβοάμ                         2             2           2     2     2
# Ῥούθ                           1             1           1     1     1
#
#               NormalizedWord
# Lemma
# Αἴγυπτος                   4
# Βαβυλών                    4
# Βαραββᾶς                   5
# Βαραχίας                   1
# Βαρθολομαῖος               1
# ...                      ...
# Ῥαμά                       1
# Ῥαχάβ                      1
# Ῥαχήλ                      1
# Ῥοβοάμ                     2
# Ῥούθ                       1
#
# [1680 rows x 6 columns]
# ===== gb_lemma_partofspeech = gb_lemma['PartOfSpeech']
# SeriesGroupBy
# -----
# {'_grouper': <pandas.core.groupby.ops.BaseGrouper object at 0x00000221D0C51D90>,
#  '_selection': 'PartOfSpeech',
#  'as_index': True,
#  'axis': 0,
#  'dropna': True,
#  'exclusions': frozenset({'Lemma'}),
#  'group_keys': True,
#  'keys': 'Lemma',
#  'level': None,
#  'obj': 0        N-
# 1        N-
# 2        N-
# 3        N-
# 4        N-
#          ..
# 18324    P-
# 18325    RA
# 18326    N-
# 18327    RA
# 18328    N-
# Name: PartOfSpeech, Length: 18329, dtype: object,
#  'observed': False,
#  'sort': True}
# -----
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x00000221D058BC50>
# ===== gb_lemma_partofspeech_count = gb_lemma_partofspeech.count()
# Series
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': SingleBlockManager
# Items: Index(['Αἴγυπτος', 'Βαβυλών', 'Βαραββᾶς', 'Βαραχίας', 'Βαρθολομαῖος',
#        'Βαριωνᾶ', 'Βεελζεβούλ', 'Βηθανία', 'Βηθλέεμ', 'Βηθσαϊδά',
#        ...
#        'ῥαπίζω', 'ῥαφίς', 'ῥύμη', 'ῥύομαι', 'ῥῆμα', 'Ῥαμά', 'Ῥαχάβ', 'Ῥαχήλ',
#        'Ῥοβοάμ', 'Ῥούθ'],
#       dtype='object', name='Lemma', length=1680)
# NumpyBlock: 1680 dtype: int64,
#  '_name': 'PartOfSpeech'}
# -----
# Lemma
# Αἴγυπτος        4
# Βαβυλών         4
# Βαραββᾶς        5
# Βαραχίας        1
# Βαρθολομαῖος    1
#                ..
# Ῥαμά            1
# Ῥαχάβ           1
# Ῥαχήλ           1
# Ῥοβοάμ          2
# Ῥούθ            1
# Name: PartOfSpeech, Length: 1680, dtype: int64
# ===== gb_lemma_partofspeech_count_sum = gb_lemma_partofspeech_count.sum()
# int64
# -----
# np.int64(18329)
# ===== gb_lemma_partofspeech_pct = gb_lemma_partofspeech_count.apply(lambda i: i / gb_lemma_partofspeech_count_sum)
# Series
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': SingleBlockManager
# Items: Index(['αὐτός', 'γάρ', 'δέ', 'εἰμί', 'εἰς', 'καί', 'λέγω', 'μή', 'οὐ', 'οὗτος',
#        'πᾶς', 'σύ', 'ἀπό', 'ἄνθρωπος', 'ἐγώ', 'ἐν', 'ἐπί', 'ἔρχομαι', 'Ἰησοῦς',
#        'ὁ', 'ὅς', 'ὅτι'],
#       dtype='object', name='Lemma')
# NumpyBlock: 22 dtype: float64,
#  '_name': 'PartOfSpeech'}
# -----
# Lemma
# αὐτός        5.008457
# γάρ          0.676524
# δέ           2.689727
# εἰμί         1.576736
# εἰς          1.189372
# καί          6.405150
# λέγω         2.755197
# μή           0.698347
# οὐ           1.080255
# οὗτος        0.802008
# πᾶς          0.703803
# σύ           2.487861
# ἀπό          0.621965
# ἄνθρωπος     0.627421
# ἐγώ          1.423973
# ἐν           1.593104
# ἐπί          0.671068
# ἔρχομαι      0.621965
# Ἰησοῦς       0.829287
# ὁ           15.178133
# ὅς           0.687435
# ὅτι          0.769273
# Name: PartOfSpeech, dtype: float64
# -----
# np.float64(49.09705930492662)

# %% [markdown]
# ## Misc

# %%
# for index, row in df.iterrows():
#     print(index)
#     print(row)

# grouped = df.groupby("Lemma")#.size()
# print(grouped.tail())

# print('=====')

# n = 25
# filtered_groups = grouped[grouped > n]
# print(filtered_groups)

# # print('=====')

# print(grouped)

#grouped["Lemma"]

# result_df = df[df['Lemma'].isin(filtered_groups)]
# print(result_df)

#g = grouped["ScriptureReference"]
# for name, group in g:
#     print(name)
#     print(group)
# gsum = g.count()
# gsum
# for name, group in gsum:
#     print(name)
#     print(group)
