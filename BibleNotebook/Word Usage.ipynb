# %% [markdown]
# # Word Usage
#
# Determines New Testament word usage.
#
# ## Load MorphGNT and Lexemes DataFrames
#
# Loads the `DF_MORPHGNT` and `DF_LEXEMES` DataFrames.
#
# Saves the total word count as `TOTAL_WORD_COUNT`
#
# DF_MORPHGNT:
# * Scripture Reference
# * Part of Speech Code
# * Inflection Codes
# * Text
# * Word
# * Normalized Word
# * Lemma
# * Book
# * Chapter
# * Verse
# * Part of Speech
# * Person
# * Tense
# * Voice
# * Mood
# * Case
# * Number
# * Gender
# * Degree
#
# DF_LEXEMES:
# * Lexeme (index)
# * Part of Speech Code
# * Full Citation Form
# * BDAG Entry
# * Danker Entry
# * Dodson Entry
# * Mounce Entry
# * Strongs
# * GK
# * Dodson Part of Speech Code
# * Gloss
# * Mounce MorphCat
# * Part of Speech

# %%
import pandas as pd
from pprint import pprint

DF_MORPHGNT = pd.read_csv("morphgnt.csv", index_col="Index")

DF_LEXEMES = pd.read_csv("lexemes.csv", index_col="Lemma")

TOTAL_WORD_COUNT = len(DF_MORPHGNT)

TOTAL_LEXEME_COUNT = len(DF_LEXEMES)


# print("===== DF_MORPHGNT")
# print(DF_MORPHGNT.__class__.__name__)
# print("-----")
# pprint(vars(DF_MORPHGNT))
# print("-----")
# pprint(DF_MORPHGNT)

# print("===== DF_LEXEMES")
# print(DF_LEXEMES.__class__.__name__)
# print("-----")
# pprint(vars(DF_LEXEMES))
# print("-----")
# pprint(DF_LEXEMES)

# print("===== TOTAL_WORD_COUNT")
# print(TOTAL_WORD_COUNT)

# print("===== TOTAL_LEXEME_COUNT")
# print(TOTAL_LEXEME_COUNT)

# %% [markdown]
# ## Determine Lemma Word Counts
#
# Creates `S_LEMMA_WORD_COUNTS` containing the word count for each lemma.

# %%
S_LEMMA_WORD_COUNTS = DF_MORPHGNT.groupby("Lemma").size()

# print("===== S_LEMMA_WORD_COUNTS")
# print(S_LEMMA_WORD_COUNTS.__class__.__name__)
# print("-----")
# pprint(vars(S_LEMMA_WORD_COUNTS))
# print("-----")
# pprint(S_LEMMA_WORD_COUNTS)

# %% [markdown]
# ## Create DataFrame for Lemma Analysis (DF_ANALYSIS)
#
# DF_ANALYSIS:
# * Lemma (index)
# * Word Count

# %%
DF_ANALYSIS = S_LEMMA_WORD_COUNTS.to_frame(name="Word Count")
DF_ANALYSIS.index.name = "Lemma"

# print("===== DF_ANALYSIS")
# print(DF_ANALYSIS.__class__.__name__)
# print("-----")
# pprint(vars(DF_ANALYSIS))
# print("-----")
# pprint(DF_ANALYSIS)

# %% [markdown]
# ## Add Word Percentage to Analysis (DF_ANALYSIS)
#
# DF_ANALYSIS:
# * Lemma (index)
# * Word Count
# * Word Percentage (new)

# %%
DF_ANALYSIS["Word Percentage"] = (DF_ANALYSIS["Word Count"] / TOTAL_WORD_COUNT) * 100

# print("===== DF_ANALYSIS")
# print(DF_ANALYSIS.__class__.__name__)
# print("-----")
# pprint(vars(DF_ANALYSIS))
# print("-----")
# pprint(DF_ANALYSIS)

# %% [markdown]
# ## Add Cumulative Percentage Column (DF_ANALYSYS)
#
# DF_ANALYSIS:
# * Lemma (index)
# * Word Count
# * Word Percentage
# * Word Percentage Cumulative (new)
# * Word Index (new)

# %%
DF_ANALYSIS = DF_ANALYSIS.sort_values("Word Percentage", ascending=False)
DF_ANALYSIS["Word Index"] = range(len(DF_ANALYSIS))
DF_ANALYSIS["Word Percentage Cumulative"] = DF_ANALYSIS["Word Percentage"].cumsum()

# DF_ANALYSIS = DF_ANALYSIS[DF_ANALYSIS["Word Index"] < 100]

# print("===== DF_ANALYSIS")
# print(DF_ANALYSIS.__class__.__name__)
# print("-----")
# pprint(vars(DF_ANALYSIS))
# print("-----")
# pprint(DF_ANALYSIS)

# %% [markdown]
# ## Merge Analysis with Lexemes (DF_MERGED)

# %%
DF_MERGED = DF_ANALYSIS.join(DF_LEXEMES)

# print("===== DF_MERGED")
# print(DF_MERGED.__class__.__name__)
# print("-----")
# pprint(vars(DF_MERGED))
# print("-----")
# pprint(DF_MERGED)

# %% [markdown]
# ## Display Word Analysis

# %%
DF_MERGED_REORDERED = DF_MERGED.reindex(
    columns=[
        "Word Index",
        "BDAG Entry",
        "Dodson Entry",
        "Part of Speech",
        "Gloss",
        "Strongs",
        "GK",
        "Word Count",
        "Word Percentage",
        "Word Percentage Cumulative",
    ]
)
DF_MERGED_REORDERED = DF_MERGED_REORDERED.head(100)

DF_MERGED_REORDERED.style.hide(axis="index").set_properties(
    subset=["Gloss", "BDAG Entry", "Dodson Entry", "Part of Speech"],
    **{"text-align": "left"}
).set_table_styles([{"selector": "th", "props": [("text-align", "left")]}]).bar(
    subset=["Word Percentage Cumulative"], vmax=100
)
# Out:
# <style type="text/css">
# #T_c03d5 th {
#   text-align: left;
# }
# #T_c03d5_row0_col1, #T_c03d5_row0_col2, #T_c03d5_row0_col3, #T_c03d5_row0_col4, #T_c03d5_row1_col1, #T_c03d5_row1_col2, #T_c03d5_row1_col3, #T_c03d5_row1_col4, #T_c03d5_row2_col1, #T_c03d5_row2_col2, #T_c03d5_row2_col3, #T_c03d5_row2_col4, #T_c03d5_row3_col1, #T_c03d5_row3_col2, #T_c03d5_row3_col3, #T_c03d5_row3_col4, #T_c03d5_row4_col1, #T_c03d5_row4_col2, #T_c03d5_row4_col3, #T_c03d5_row4_col4, #T_c03d5_row5_col1, #T_c03d5_row5_col2, #T_c03d5_row5_col3, #T_c03d5_row5_col4, #T_c03d5_row6_col1, #T_c03d5_row6_col2, #T_c03d5_row6_col3, #T_c03d5_row6_col4, #T_c03d5_row7_col1, #T_c03d5_row7_col2, #T_c03d5_row7_col3, #T_c03d5_row7_col4, #T_c03d5_row8_col1, #T_c03d5_row8_col2, #T_c03d5_row8_col3, #T_c03d5_row8_col4, #T_c03d5_row9_col1, #T_c03d5_row9_col2, #T_c03d5_row9_col3, #T_c03d5_row9_col4, #T_c03d5_row10_col1, #T_c03d5_row10_col2, #T_c03d5_row10_col3, #T_c03d5_row10_col4, #T_c03d5_row11_col1, #T_c03d5_row11_col2, #T_c03d5_row11_col3, #T_c03d5_row11_col4, #T_c03d5_row12_col1, #T_c03d5_row12_col2, #T_c03d5_row12_col3, #T_c03d5_row12_col4, #T_c03d5_row13_col1, #T_c03d5_row13_col2, #T_c03d5_row13_col3, #T_c03d5_row13_col4, #T_c03d5_row14_col1, #T_c03d5_row14_col2, #T_c03d5_row14_col3, #T_c03d5_row14_col4, #T_c03d5_row15_col1, #T_c03d5_row15_col2, #T_c03d5_row15_col3, #T_c03d5_row15_col4, #T_c03d5_row16_col1, #T_c03d5_row16_col2, #T_c03d5_row16_col3, #T_c03d5_row16_col4, #T_c03d5_row17_col1, #T_c03d5_row17_col2, #T_c03d5_row17_col3, #T_c03d5_row17_col4, #T_c03d5_row18_col1, #T_c03d5_row18_col2, #T_c03d5_row18_col3, #T_c03d5_row18_col4, #T_c03d5_row19_col1, #T_c03d5_row19_col2, #T_c03d5_row19_col3, #T_c03d5_row19_col4, #T_c03d5_row20_col1, #T_c03d5_row20_col2, #T_c03d5_row20_col3, #T_c03d5_row20_col4, #T_c03d5_row21_col1, #T_c03d5_row21_col2, #T_c03d5_row21_col3, #T_c03d5_row21_col4, #T_c03d5_row22_col1, #T_c03d5_row22_col2, #T_c03d5_row22_col3, #T_c03d5_row22_col4, #T_c03d5_row23_col1, #T_c03d5_row23_col2, #T_c03d5_row23_col3, #T_c03d5_row23_col4, #T_c03d5_row24_col1, #T_c03d5_row24_col2, #T_c03d5_row24_col3, #T_c03d5_row24_col4, #T_c03d5_row25_col1, #T_c03d5_row25_col2, #T_c03d5_row25_col3, #T_c03d5_row25_col4, #T_c03d5_row26_col1, #T_c03d5_row26_col2, #T_c03d5_row26_col3, #T_c03d5_row26_col4, #T_c03d5_row27_col1, #T_c03d5_row27_col2, #T_c03d5_row27_col3, #T_c03d5_row27_col4, #T_c03d5_row28_col1, #T_c03d5_row28_col2, #T_c03d5_row28_col3, #T_c03d5_row28_col4, #T_c03d5_row29_col1, #T_c03d5_row29_col2, #T_c03d5_row29_col3, #T_c03d5_row29_col4, #T_c03d5_row30_col1, #T_c03d5_row30_col2, #T_c03d5_row30_col3, #T_c03d5_row30_col4, #T_c03d5_row31_col1, #T_c03d5_row31_col2, #T_c03d5_row31_col3, #T_c03d5_row31_col4, #T_c03d5_row32_col1, #T_c03d5_row32_col2, #T_c03d5_row32_col3, #T_c03d5_row32_col4, #T_c03d5_row33_col1, #T_c03d5_row33_col2, #T_c03d5_row33_col3, #T_c03d5_row33_col4, #T_c03d5_row34_col1, #T_c03d5_row34_col2, #T_c03d5_row34_col3, #T_c03d5_row34_col4, #T_c03d5_row35_col1, #T_c03d5_row35_col2, #T_c03d5_row35_col3, #T_c03d5_row35_col4, #T_c03d5_row36_col1, #T_c03d5_row36_col2, #T_c03d5_row36_col3, #T_c03d5_row36_col4, #T_c03d5_row37_col1, #T_c03d5_row37_col2, #T_c03d5_row37_col3, #T_c03d5_row37_col4, #T_c03d5_row38_col1, #T_c03d5_row38_col2, #T_c03d5_row38_col3, #T_c03d5_row38_col4, #T_c03d5_row39_col1, #T_c03d5_row39_col2, #T_c03d5_row39_col3, #T_c03d5_row39_col4, #T_c03d5_row40_col1, #T_c03d5_row40_col2, #T_c03d5_row40_col3, #T_c03d5_row40_col4, #T_c03d5_row41_col1, #T_c03d5_row41_col2, #T_c03d5_row41_col3, #T_c03d5_row41_col4, #T_c03d5_row42_col1, #T_c03d5_row42_col2, #T_c03d5_row42_col3, #T_c03d5_row42_col4, #T_c03d5_row43_col1, #T_c03d5_row43_col2, #T_c03d5_row43_col3, #T_c03d5_row43_col4, #T_c03d5_row44_col1, #T_c03d5_row44_col2, #T_c03d5_row44_col3, #T_c03d5_row44_col4, #T_c03d5_row45_col1, #T_c03d5_row45_col2, #T_c03d5_row45_col3, #T_c03d5_row45_col4, #T_c03d5_row46_col1, #T_c03d5_row46_col2, #T_c03d5_row46_col3, #T_c03d5_row46_col4, #T_c03d5_row47_col1, #T_c03d5_row47_col2, #T_c03d5_row47_col3, #T_c03d5_row47_col4, #T_c03d5 ...
