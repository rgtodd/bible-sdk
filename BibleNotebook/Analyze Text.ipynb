# %% [markdown]
# # Word Usage
#
# Determines New Testament word usage.
#
# ## Define Files Names

# %%
LEXEMES_CSV = "lexemes.csv"
MORPHGNT_CSV = "morphgnt.csv"

# %% [markdown]
# ## Define Column Names

# %%
BDAG_ENTRY = "BDAG Entry"
BOOK = "Book"
CHAPTER = "Chapter"
DODSON_ENTRY = "Dodson Entry"
GK = "GK"
GLOSS = "Gloss"
INDEX = "Index"
LEMMA = "Lemma"
LEXICAL_ENTRY = "Lexical Entry"
NEW_TESTAMENT_WORD_INDEX = "New Testament Word Index"
PART_OF_SPEECH = "Part of Speech"
STRONGS = "Strongs"
WORD_COUNT = "Word Count"
WORD_INDEX = "Word Index"
WORD_PERCENTAGE = "Word Percentage"
WORD_PERCENTAGE_CUMULATIVE = "Word Percentage Cumulative"

# %% [markdown]
# ## Define Book Names

# %%
BOOKS = {
    1: "Matthew",
    2: "Mark",
    3: "Luke",
    4: "John",
    5: "Acts",
    6: "Romans",
    7: "I Corinthians",
    8: "II Corinthians",
    9: "Galatians",
    10: "Ephesians",
    11: "Philippians",
    12: "Colossians",
    13: "I Thessalonians",
    14: "II Thessalonians",
    15: "I Timothy",
    16: "II Timothy",
    17: "Titus",
    18: "Philemon",
    19: "Hebrews",
    20: "James",
    21: "I Peter",
    22: "II Peter",
    23: "I John",
    24: "II John",
    25: "III John",
    26: "Jude",
    27: "Revelations",
}

# %% [markdown]
# ## Create Report Class

# %%
class Report:

    def __init__(self, df):

        self.df = df
        self.properties = {}

    def get_styler(self, count=None):
         
        df_report = self.df.head(count) if count else self.df

        report_styler = (
            df_report.style.hide(axis="index")
            .format(
                {WORD_PERCENTAGE: "{:.2%}", WORD_PERCENTAGE_CUMULATIVE: "{:.2%}"},
                precision=2,
                na_rep=""
            )
            .set_properties(
                subset=[GLOSS, LEXICAL_ENTRY, PART_OF_SPEECH],
                **{"text-align": "left"},
            )
            .set_properties(
                subset=[WORD_COUNT, WORD_PERCENTAGE, WORD_PERCENTAGE_CUMULATIVE],
                **{"text-align": "right"},
            )
            .set_table_styles([{"selector": "th", "props": [("text-align", "left")]}])
            .bar(subset=[WORD_PERCENTAGE_CUMULATIVE], color="LightBlue", vmax=1)
        )

        if NEW_TESTAMENT_WORD_INDEX in df_report:
            report_styler = report_styler.apply(
                lambda x: ["background: LightGreen" if v > 100 else "" for v in x],
                subset=[NEW_TESTAMENT_WORD_INDEX],
                axis="columns",
            )

        return report_styler

# %% [markdown]
# ## Create Analyzer Class

# %%
import pandas as pd
from pprint import pprint


class Analyzer:

    def __init__(self):
        self.enable_dump = False

    def load_data(self):
        self.DF_MORPHGNT = pd.read_csv(MORPHGNT_CSV, index_col=INDEX)
        self.DF_LEXEMES = pd.read_csv(LEXEMES_CSV, index_col=LEMMA)
        self._dump(self.DF_MORPHGNT, "DF_MORPHGNT")
        self._dump(self.DF_LEXEMES, "DF_LEXEMES")

        self.TOTAL_WORD_COUNT = len(self.DF_MORPHGNT)
        self.TOTAL_LEXEME_COUNT = len(self.DF_LEXEMES)

    def get_new_testament_report(self):

        report_df = self._create_report_df(self.DF_MORPHGNT)

        return Report(report_df)

    def get_book_report(self, book, chapter=None, add_nt_word_index=None):

        df_morphgnt_book = self.DF_MORPHGNT[(self.DF_MORPHGNT[BOOK] == book)]
        if chapter:
            df_morphgnt_book = df_morphgnt_book[(df_morphgnt_book[CHAPTER] == chapter)]
        self._dump(df_morphgnt_book, "df_morphgnt_book")

        report_df = self._create_report_df(df_morphgnt_book)

        if add_nt_word_index:
            new_testament_report_df = self._create_report_df(self.DF_MORPHGNT)
            new_testament_word_index = new_testament_report_df[WORD_INDEX]
            report_df.insert(
                loc=1, column=NEW_TESTAMENT_WORD_INDEX, value=new_testament_word_index
            )

        book_top_100 = report_df[
            (report_df[WORD_INDEX] < 100) | (report_df[NEW_TESTAMENT_WORD_INDEX] < 100)
        ]
        book_top_100 = book_top_100.drop(columns=[WORD_PERCENTAGE_CUMULATIVE])
        book_top_100[WORD_PERCENTAGE_CUMULATIVE] = book_top_100[WORD_PERCENTAGE].cumsum()

        return Report(book_top_100)
    
    def _create_report_df(self, df_morphgnt):

        total_word_count = len(df_morphgnt)

        s_lemma_word_counts = df_morphgnt.groupby(LEMMA).size()
        self._dump(s_lemma_word_counts, "S_LEMMA_WORD_COUNTS")

        df_analysis = s_lemma_word_counts.to_frame(name=WORD_COUNT)
        df_analysis.index.name = LEMMA
        df_analysis[WORD_PERCENTAGE] = df_analysis[WORD_COUNT] / total_word_count
        self._dump(df_analysis, "DF_ANALYSIS")

        df_analysis_sorted = df_analysis.sort_values(WORD_PERCENTAGE, ascending=False)
        df_analysis_sorted[WORD_INDEX] = range(1, len(df_analysis_sorted) + 1)
        df_analysis_sorted[WORD_PERCENTAGE_CUMULATIVE] = df_analysis_sorted[
            WORD_PERCENTAGE
        ].cumsum()
        self._dump(df_analysis_sorted, "DF_ANALYSIS_SORTED")

        df_merged = df_analysis_sorted.join(self.DF_LEXEMES)
        self._dump(df_merged, "DF_MERGED")

        df_merged[LEXICAL_ENTRY] = df_merged[DODSON_ENTRY].combine_first(df_merged[BDAG_ENTRY])

        df_report = df_merged.reindex(
            columns=[
                WORD_INDEX,
                LEXICAL_ENTRY,
                PART_OF_SPEECH,
                GLOSS,
                STRONGS,
                GK,
                WORD_COUNT,
                WORD_PERCENTAGE,
                WORD_PERCENTAGE_CUMULATIVE,
            ]
        )
        self._dump(df_report, "DF_REPORT")

        return df_report

    def _dump(self, object, name):

        if self.enable_dump:
            print(f"===== {name}")
            print(object.__class__.__name__)
            print("-----")
            pprint(vars(object))
            print("-----")
            pprint(object)

# %% [markdown]
# ## Analyze New Testament

# %%
ANALYZER = Analyzer()

ANALYZER.load_data()

new_testament_report = ANALYZER.get_new_testament_report()

new_testament_report_styler = new_testament_report.get_styler(100)
new_testament_report_styler
# Out:
# <style type="text/css">
# #T_00b4f th {
#   text-align: left;
, #T_00b4f_row10_col6, #T_00b4f_row10_col7, #T_00b4f_row11_col6, #T_00b4f_row11_col7, #T_00b4f_row12_col6, #T_00b4f_row12_col7, #T_00b4f_row13_col6, #T_00b4f_row13_col7, #T_00b4f_row14_col6, #T_00b4f_row14_col7, #T_00b4f_row15_col6, #T_00b4f_row15_col7, #T_00b4f_row16_col6, #T_00b4f_row16_col7, #T_00b4f_row17_col6, #T_00b4f_row17_col7, #T_00b4f_row18_col6, #T_00b4f_row18_col7, #T_00b4f_row19_col6, #T_00b4f_row19_col7, #T_00b4f_row20_col6, #T_00b4f_row20_col7, #T_00b4f_row21_col6, #T_00b4f_row21_col7, #T_00b4f_row22_col6, #T_00b4f_row22_col7, #T_00b4f_row23_col6, #T_00b4f_row23_col7, #T_00b4f_row24_col6, #T_00b4f_row24_col7, #T_00b4f_row25_col6, #T_00b4f_row25_col7, #T_00b4f_row26_col6, #T_00b4f_row26_col7, #T_00b4f_row27_col6, #T_00b4f_row27_col7, #T_00b4f_row28_col6, #T_00b4f_row28_col7, #T_00b4f_row29_col6, #T_00b4f_row29_col7, #T_00b4f_row30_col6, #T_00b4f_row30_col7, #T_00b4f_row31_col6, #T_00b4f_row31_col7, #T_00b4f_row32_col6, #T_00b4f_row32_col7, #T_00b4f_row33_col6, #T_00b4f_row33_col7, #T_00b4f_row34_col6, #T_00b4f_row34_col7, #T_00b4f_row35_col6, #T_00b4f_row35_col7, #T_00b4f_row36_col6, #T_00b4f_row36_col7, #T_00b4f_row37_col6, #T_00b4f_row37_col7, #T_00b4f_row38_col6, #T_00b4f_row38_col7, #T_00b4f_row39_col6, #T_00b4f

# %% [markdown]
# ## Analyze Book

# %%
ANALYZER = Analyzer()

ANALYZER.load_data()

book_report = ANALYZER.get_book_report(1, 1, add_nt_word_index=True)

report_styler = book_report.get_styler()
report_styler
# Out:
# <style type="text/css">
# #T_4d103 th {
#   text-align: left;
# }
# #T_4d103_row0_col2, #T_4d103_row0_col3, #T_4d103_row0_col4, #T_4d103_row1_col2, #T_4d103_row1_col3, #T_4d103_row1_col4, #T_4d103_row2_col2, #T_4d103_row2_col3, #T_4d103_row2_col4, #T_4d103_row3_col2, #T_4d103_row3_col3, #T_4d103_row3_col4, #T_4d103_row4_col2, #T_4d103_row4_col3, #T_4d103_row4_col4, #T_4d103_row5_col2, #T_4d103_row5_col3, #T_4d103_row5_col4, #T_4d103_row6_col2, #T_4d103_row6_col3, #T_4d103_row6_col4, #T_4d103_row7_col2, #T_4d103_row7_col3, #T_4d103_row7_col4, #T_4d103_row8_col2, #T_4d103_row8_col3, #T_4d103_row8_col4, #T_4d103_row9_col2, #T_4d103_row9_col3, #T_4d103_row9_col4, #T_4d103_row10_col2, #T_4d103_row10_col3, #T_4d103_row10_col4, #T_4d103_row11_col2, #T_4d103_row11_col3, #T_4d103_row11_col4, #T_4d103_row12_col2, #T_4d103_row12_col3, #T_4d103_row12_col4, #T_4d103_row13_col2, #T_4d103_row13_col3, #T_4d103_row13_col4, #T_4d103_row14_col2, #T_4d103_row14_col3, #T_4d103_row14_col4, #T_4d103_row15_col2, #T_4d103_row15_col3, #T_4d103_row15_col4, #T_4d103_row16_col2, #T_4d103_row16_col3, #T_4d103_row16_col4, #T_4d103_row17_col2, #T_4d103_row17_col3, #T_4d103_row17_col4, #T_4d103_row18_col2, #T_4d103_row18_col3, #T_4d103_row18_col4, #T_4d103_row19_col2, #T_4d103_row19_col3, #T_4d103_row19_col4, #T_4d103_row20_col2, #T_4d103_row20_col3, #T_4d103_row20_col4, #T_4d103_row21_col2, #T_4d103_row21_col3, #T_4d103_row21_col4, #T_4d103_row22_col2, #T_4d103_row22_col3, #T_4d103_row22_col4, #T_4d103_row23_col2, #T_4d103_row23_col3, #T_4d103_row23_col4, #T_4d103_row24_col2, #T_4d103_row24_col3, #T_4d103_row24_col4, #T_4d103_row25_col2, #T_4d103_row25_col3, #T_4d103_row25_col4, #T_4d103_row26_col2, #T_4d103_row26_col3, #T_4d103_row26_col4, #T_4d103_row27_col2, #T_4d103_row27_col3, #T_4d103_row27_col4, #T_4d103_row28_col2, #T_4d103_row28_col3, #T_4d103_row28_col4, #T_4d103_row29_col2, #T_4d103_row29_col3, #T_4d103_row29_col4, #T_4d103_row30_col2, #T_4d103_row30_col3, #T_4d103_row30_col4, #T_4d103_row31_col2, #T_4d103_row31_col3, #T_4d103_row31_col4, #T_4d103_row32_col2, #T_4d103_row32_col3, #T_4d103_row32_col4, #T_4d103_row33_col2, #T_4d103_row33_col3, #T_4d103_row33_col4, #T_4d103_row34_col2, #T_4d103_row34_col3, #T_4d103_row34_col4, #T_4d103_row35_col2, #T_4d103_row35_col3, #T_4d103_row35_col4, #T_4d103_row36_col2, #T_4d103_row36_col3, #T_4d103_row36_col4, #T_4d103_row37_col2, #T_4d103_row37_col3, #T_4d103_row37_col4, #T_4d103_row38_col2, #T_4d103_row38_col3, #T_4d103_row38_col4, #T_4d103_row39_col2, #T_4d103_row39_col3, #T_4d103_row39_col4, #T_4d103_row40_col2, #T_4d103_row40_col3, #T_4d103_row40_col4, #T_4d103_row41_col2, #T_4d103_row41_col3, #T_4d103_row41_col4, #T_4d103_row42_col2, #T_4d103_row42_col3, #T_4d103_row42_col4, #T_4d103_row43_col2, #T_4d103_row43_col3, #T_4d103_row43_col4, #T_4d103_row44_col2, #T_4d103_row44_col3, #T_4d103_row44_col4, #T_4d103_row45_col2, #T_4d103_row45_col3, #T_4d103_row45_col4, #T_4d103_row46_col2, #T_4d103_row46_col3, #T_4d103_row46_col4, #T_4d103_row47_col2, #T_4d103_row47_col3, #T_4d103_row47_col4, #T_4d103_row48_col2, #T_4d103_row48_col3, #T_4d103_row48_col4, #T_4d103_row49_col2, #T_4d103_row49_col3, #T_4d103_row49_col4, #T_4d103_row50_col2, #T_4d103_row50_col3, #T_4d103_row50_col4, #T_4d103_row51_col2, #T_4d103_row51_col3, #T_4d103_row51_col4, #T_4d103_row52_col2, #T_4d103_row52_col3, #T_4d103_row52_col4, #T_4d103_row53_col2, #T_4d103_row53_col3, #T_4d103_row53_col4, #T_4d103_row54_col2, #T_4d103_row54_col3, #T_4d103_row54_col4, #T_4d103_row55_col2, #T_4d103_row55_col3, #T_4d103_row55_col4, #T_4d103_row56_col2, #T_4d103_row56_col3, #T_4d103_row56_col4, #T_4d103_row57_col2, #T_4d103_row57_col3, #T_4d103_row57_col4, #T_4d103_row58_col2, #T_4d103_row58_col3, #T_4d103_row58_col4, #T_4d103_row59_col2, #T_4d103_row59_col3, #T_4d103_row59_col4, #T_4d103_row60_col2, #T_4d103_row60_col3, #T_4d103_row60_col4, #T_4d103_row61_col2, #T_4d103_row61_col3, #T_4d103_row61_col4, #T_4d103_row62_col2, #T_4d103_row62_col3, #T_4d103_row62_col4, #T_4d103_row63_col2, #T_4d103_row63_col3, #T_4d103_row63_col4 ...
#   text-align: left;
# }
# #T_4d103_row0_col7, #T_4d103_row0_col8, #T_4d103_row1_col7, #T_4d103_row1_col8, #T_4d103_row2_col7, #T_4d103_row2_col8, #T_4d103_row3_col7, #T_4d103_row3_col8, #T_4d103_row4_col7, #T_4d103_row4_col8, #T_4d103_row5_col7, #T_4d103_row5_col8, #T_4d103_row6_col7, #T_4d103_row6_col8, #T_4d103_row7_col7, #T_4d103_row7_col8, #T_4d103_row8_col7, #T_4d103_row8_col8, #T_4d103_row9_col7, #T_4d103_row9_col8, #T_4d103_row10_col7, #T_4d103_row10_col8, #T_4d103_row11_col7, #T_4d103_row11_col8, #T_4d103_row12_col7, #T_4d103_row12_col8, #T_4d103_row13_col7, #T_4d103_row13_col8, #T_4d103_row14_col7, #T_4d103_row14_col8, #T_4d103_row15_col7, #T_4d103_row15_col8, #T_4d103_row16_col7, #T_4d103_row16_col8, #T_4d103_row17_col7, #T_4d103_row17_col8, #T_4d103_row18_col7, #T_4d103_row18_col8, #T_4d103_row19_col7, #T_4d103_row19_col8, #T_4d103_row20_col7, #T_4d103_row20_col8, #T_4d103_row21_col7, #T_4d103_row21_col8, #T_4d103_row22_co

# %% [markdown]
# ## Create Usage Reports

# %%
from pathlib import Path

ANALYZER = Analyzer()
ANALYZER.load_data()

Path("reports").mkdir(exist_ok=True)

# Create New Testament summary report.
#
new_testament_report = ANALYZER.get_new_testament_report()
new_testament_report_styler = new_testament_report.get_styler(100)

report_html = f"<h2>New Testament</h2>"
report_html +=  new_testament_report_styler.to_html()
with open("reports/words_00_new_testament.html", "w", encoding="utf-8") as file:
    file.write(report_html)

# Create book detail reports.
#
for book_number in BOOKS:
    book_name = BOOKS[book_number]
    book_report = ANALYZER.get_book_report(book_number, add_nt_word_index=True)
    report_styler = book_report.get_styler()

    report_html = f"<h2>{book_name}</h2>"
    report_html += report_styler.to_html()
    with open(f"reports/words_{book_number:02d}_{book_name}.html", "w", encoding="utf-8") as file:
        file.write(report_html)
