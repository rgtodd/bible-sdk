# %% [markdown]
# # Word Usage
#
# Determines New Testament word usage.
#
# ## Define Files Names

# %%
LEXEMES_CSV = "lexemes.csv"
MORPHGNT_CSV = "morphgnt.csv"

# %% [markdown]
# ## Define Column Names

# %%
BDAG_ENTRY = "BDAG Entry"
BOOK = "Book"
CHAPTER = "Chapter"
DODSON_ENTRY = "Dodson Entry"
GK = "GK"
GLOSS = "Gloss"
INDEX = "Index"
LEMMA = "Lemma"
NEW_TESTAMENT_WORD_INDEX = "New Testament Word Index"
PART_OF_SPEECH = "Part of Speech"
STRONGS = "Strongs"
WORD_COUNT = "Word Count"
WORD_INDEX = "Word Index"
WORD_PERCENTAGE = "Word Percentage"
WORD_PERCENTAGE_CUMULATIVE = "Word Percentage Cumulative"

# %% [markdown]
# ## Create Analyzer Class

# %%
import pandas as pd
from pprint import pprint


class Analyzer:

    def __init__(self):
        self.enable_dump = False

    def load_data(self):
        self.DF_MORPHGNT = pd.read_csv(MORPHGNT_CSV, index_col=INDEX)
        self.DF_LEXEMES = pd.read_csv(LEXEMES_CSV, index_col=LEMMA)
        self._dump(self.DF_MORPHGNT, "DF_MORPHGNT")
        self._dump(self.DF_LEXEMES, "DF_LEXEMES")

        self.TOTAL_WORD_COUNT = len(self.DF_MORPHGNT)
        self.TOTAL_LEXEME_COUNT = len(self.DF_LEXEMES)

    def get_new_testament_report(self):

        return self._get_report(self.DF_MORPHGNT)

    def get_book_report(self, book, chapter=None, add_nt_word_index=None):

        df_morphgnt_book = self.DF_MORPHGNT[(self.DF_MORPHGNT[BOOK] == book)]
        if chapter:
            df_morphgnt_book = df_morphgnt_book[(df_morphgnt_book[CHAPTER] == chapter)]
        self._dump(df_morphgnt_book, "df_morphgnt_book")

        report = self._get_report(df_morphgnt_book)

        if add_nt_word_index:
            new_testament_report = self.get_new_testament_report()
            new_testament_word_index = new_testament_report[WORD_INDEX]
            report.insert(
                loc=1, column=NEW_TESTAMENT_WORD_INDEX, value=new_testament_word_index
            )

        return report

    def get_report_styler(self, df_report):

        report_styler = (
            df_report.style.hide(axis="index")
            .format(
                {WORD_PERCENTAGE: "{:.2%}", WORD_PERCENTAGE_CUMULATIVE: "{:.2%}"},
                precision=2,
            )
            .set_properties(
                subset=[GLOSS, BDAG_ENTRY, DODSON_ENTRY, PART_OF_SPEECH],
                **{"text-align": "left"},
            )
            .set_properties(
                subset=[WORD_COUNT, WORD_PERCENTAGE, WORD_PERCENTAGE_CUMULATIVE],
                **{"text-align": "right"},
            )
            .set_table_styles([{"selector": "th", "props": [("text-align", "left")]}])
            .bar(subset=[WORD_PERCENTAGE_CUMULATIVE], color="LightBlue", vmax=1)
        )

        if NEW_TESTAMENT_WORD_INDEX in df_report:
            report_styler = report_styler.apply(
                lambda x: ["background: LightGreen" if v > 100 else "" for v in x],
                subset=[NEW_TESTAMENT_WORD_INDEX],
                axis="columns",
            )

        return report_styler

    def _get_report(self, df_morphgnt):

        total_word_count = len(df_morphgnt)

        s_lemma_word_counts = df_morphgnt.groupby(LEMMA).size()
        self._dump(s_lemma_word_counts, "S_LEMMA_WORD_COUNTS")

        df_analysis = s_lemma_word_counts.to_frame(name=WORD_COUNT)
        df_analysis.index.name = LEMMA
        df_analysis[WORD_PERCENTAGE] = df_analysis[WORD_COUNT] / total_word_count
        self._dump(df_analysis, "DF_ANALYSIS")

        df_analysis_sorted = df_analysis.sort_values(WORD_PERCENTAGE, ascending=False)
        df_analysis_sorted[WORD_INDEX] = range(1, len(df_analysis_sorted) + 1)
        df_analysis_sorted[WORD_PERCENTAGE_CUMULATIVE] = df_analysis_sorted[
            WORD_PERCENTAGE
        ].cumsum()
        self._dump(df_analysis_sorted, "DF_ANALYSIS_SORTED")

        df_merged = df_analysis_sorted.join(self.DF_LEXEMES)
        self._dump(df_merged, "DF_MERGED")

        df_report = df_merged.reindex(
            columns=[
                WORD_INDEX,
                BDAG_ENTRY,
                DODSON_ENTRY,
                PART_OF_SPEECH,
                GLOSS,
                STRONGS,
                GK,
                WORD_COUNT,
                WORD_PERCENTAGE,
                WORD_PERCENTAGE_CUMULATIVE,
            ]
        )
        self._dump(df_report, "DF_REPORT")

        return df_report

    def _dump(self, object, name):

        if self.enable_dump:
            print(f"===== {name}")
            print(object.__class__.__name__)
            print("-----")
            pprint(vars(object))
            print("-----")
            pprint(object)

# %% [markdown]
# ## Analyze New Testament

# %%
ANALYZER = Analyzer()

ANALYZER.load_data()

new_testament_report = ANALYZER.get_new_testament_report()

new_testament_report_styler = ANALYZER.get_report_styler(new_testament_report.head(100))

report_html = new_testament_report_styler.to_html()

with open("new_testament_report.html", "w", encoding="utf-8") as file:
    file.write(report_html)

# %% [markdown]
# ## Analyze Book

# %%
ANALYZER = Analyzer()

ANALYZER.load_data()

book_report = ANALYZER.get_book_report(4, 1, add_nt_word_index=True)

book_top_100 = book_report[
    (book_report[WORD_INDEX] < 100) | (book_report[NEW_TESTAMENT_WORD_INDEX] < 100)
]
book_top_100 = book_top_100.drop(columns=[WORD_PERCENTAGE_CUMULATIVE])
book_top_100[WORD_PERCENTAGE_CUMULATIVE] = book_top_100[WORD_PERCENTAGE].cumsum()

report_styler = ANALYZER.get_report_styler(book_top_100)
report_styler
# Out:
# <style type="text/css">
# #T_b605c th {
#   text-align: left;
# }
# #T_b605c_row0_col2, #T_b605c_row0_col3, #T_b605c_row0_col4, #T_b605c_row0_col5, #T_b605c_row1_col2, #T_b605c_row1_col3, #T_b605c_row1_col4, #T_b605c_row1_col5, #T_b605c_row2_col2, #T_b605c_row2_col3, #T_b605c_row2_col4, #T_b605c_row2_col5, #T_b605c_row3_col2, #T_b605c_row3_col3, #T_b605c_row3_col4, #T_b605c_row3_col5, #T_b605c_row4_col2, #T_b605c_row4_col3, #T_b605c_row4_col4, #T_b605c_row4_col5, #T_b605c_row5_col2, #T_b605c_row5_col3, #T_b605c_row5_col4, #T_b605c_row5_col5, #T_b605c_row6_col2, #T_b605c_row6_col3, #T_b605c_row6_col4, #T_b605c_row6_col5, #T_b605c_row7_col2, #T_b605c_row7_col3, #T_b605c_row7_col4, #T_b605c_row7_col5, #T_b605c_row8_col2, #T_b605c_row8_col3, #T_b605c_row8_col4, #T_b605c_row8_col5, #T_b605c_row9_col2, #T_b605c_row9_col3, #T_b605c_row9_col4, #T_b605c_row9_col5, #T_b605c_row10_col2, #T_b605c_row10_col3, #T_b605c_row10_col4, #T_b605c_row10_col5, #T_b605c_row11_col2, #T_b605c_row11_col3, #T_b605c_row11_col4, #T_b605c_row11_col5, #T_b605c_row12_col2, #T_b605c_row12_col3, #T_b605c_row12_col4, #T_b605c_row12_col5, #T_b605c_row13_col2, #T_b605c_row13_col3, #T_b605c_row13_col4, #T_b605c_row13_col5, #T_b605c_row14_col2, #T_b605c_row14_col3, #T_b605c_row14_col4, #T_b605c_row14_col5, #T_b605c_row15_col2, #T_b605c_row15_col3, #T_b605c_row15_col4, #T_b605c_row15_col5, #T_b605c_row16_col2, #T_b605c_row16_col3, #T_b605c_row16_col4, #T_b605c_row16_col5, #T_b605c_row17_col2, #T_b605c_row17_col3, #T_b605c_row17_col4, #T_b605c_row17_col5, #T_b605c_row18_col2, #T_b605c_row18_col3, #T_b605c_row18_col4, #T_b605c_row18_col5, #T_b605c_row19_col2, #T_b605c_row19_col3, #T_b605c_row19_col4, #T_b605c_row19_col5, #T_b605c_row20_col2, #T_b605c_row20_col3, #T_b605c_row20_col4, #T_b605c_row20_col5, #T_b605c_row21_col2, #T_b605c_row21_col3, #T_b605c_row21_col4, #T_b605c_row21_col5, #T_b605c_row22_col2, #T_b605c_row22_col3, #T_b605c_row22_col4, #T_b605c_row22_col5, #T_b605c_row23_col2, #T_b605c_row23_col3, #T_b605c_row23_col4, #T_b605c_row23_col5, #T_b605c_row24_col2, #T_b605c_row24_col3, #T_b605c_row24_col4, #T_b605c_row24_col5, #T_b605c_row25_col2, #T_b605c_row25_col3, #T_b605c_row25_col4, #T_b605c_row25_col5, #T_b605c_row26_col2, #T_b605c_row26_col3, #T_b605c_row26_col4, #T_b605c_row26_col5, #T_b605c_row27_col2, #T_b605c_row27_col3, #T_b605c_row27_col4, #T_b605c_row27_col5, #T_b605c_row28_col2, #T_b605c_row28_col3, #T_b605c_row28_col4, #T_b605c_row28_col5, #T_b605c_row29_col2, #T_b605c_row29_col3, #T_b605c_row29_col4, #T_b605c_row29_col5, #T_b605c_row30_col2, #T_b605c_row30_col3, #T_b605c_row30_col4, #T_b605c_row30_col5, #T_b605c_row31_col2, #T_b605c_row31_col3, #T_b605c_row31_col4, #T_b605c_row31_col5, #T_b605c_row32_col2, #T_b605c_row32_col3, #T_b605c_row32_col4, #T_b605c_row32_col5, #T_b605c_row33_col2, #T_b605c_row33_col3, #T_b605c_row33_col4, #T_b605c_row33_col5, #T_b605c_row34_col2, #T_b605c_row34_col3, #T_b605c_row34_col4, #T_b605c_row34_col5, #T_b605c_row35_col2, #T_b605c_row35_col3, #T_b605c_row35_col4, #T_b605c_row35_col5, #T_b605c_row36_col2, #T_b605c_row36_col3, #T_b605c_row36_col4, #T_b605c_row36_col5, #T_b605c_row37_col2, #T_b605c_row37_col3, #T_b605c_row37_col4, #T_b605c_row37_col5, #T_b605c_row38_col2, #T_b605c_row38_col3, #T_b605c_row38_col4, #T_b605c_row38_col5, #T_b605c_row39_col2, #T_b605c_row39_col3, #T_b605c_row39_col4, #T_b605c_row39_col5, #T_b605c_row40_col2, #T_b605c_row40_col3, #T_b605c_row40_col4, #T_b605c_row40_col5, #T_b605c_row41_col2, #T_b605c_row41_col3, #T_b605c_row41_col4, #T_b605c_row41_col5, #T_b605c_row42_col2, #T_b605c_row42_col3, #T_b605c_row42_col4, #T_b605c_row42_col5, #T_b605c_row43_col2, #T_b605c_row43_col3, #T_b605c_row43_col4, #T_b605c_row43_col5, #T_b605c_row44_col2, #T_b605c_row44_col3, #T_b605c_row44_col4, #T_b605c_row44_col5, #T_b605c_row45_col2, #T_b605c_row45_col3, #T_b605c_row45_col4, #T_b605c_row45_col5, #T_b605c_row46_col2, #T_b605c_row46_col3, #T_b605c_row46_col4, #T_b605c_row46_col5, #T_b605c_row47_col2, #T_b605c_row47_col3, #T_b605c_row47_col4, #T_b605c_row47_col5, #T_b605c ...
