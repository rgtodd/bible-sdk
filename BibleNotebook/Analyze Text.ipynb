# %% [markdown]
# # Word Usage
#
# Determines New Testament word usage.
#
# ## Define Files Names

# %%
LEXEMES_CSV = "lexemes.csv"
MORPHGNT_CSV = "morphgnt.csv"
MOUNCE_TXT = "../BibleCore/resources/mounce.txt"

# %% [markdown]
# ## Analyze New Testament

# %%
from biblesdk.classes import Analyzer

ANALYZER = Analyzer(200)

ANALYZER.load_data(MORPHGNT_CSV, LEXEMES_CSV, MOUNCE_TXT)

new_testament_report = ANALYZER.get_new_testament_report()

new_testament_report_styler = new_testament_report.get_styler()
new_testament_report_styler
# Out:
# <style type="text/css">
# #T_ae1c2 th {
#   text-align: left;
# }
# #T_ae1c2_row0_col1, #T_ae1c2_row0_col2, #T_ae1c2_row0_col3, #T_ae1c2_row1_col1, #T_ae1c2_row1_col2, #T_ae1c2_row1_col3, #T_ae1c2_row2_col1, #T_ae1c2_row2_col2, #T_ae1c2_row2_col3, #T_ae1c2_row3_col1, #T_ae1c2_row3_col2, #T_ae1c2_row3_col3, #T_ae1c2_row4_col1, #T_ae1c2_row4_col2, #T_ae1c2_row4_col3, #T_ae1c2_row5_col1, #T_ae1c2_row5_col2, #T_ae1c2_row5_col3, #T_ae1c2_row6_col1, #T_ae1c2_row6_col2, #T_ae1c2_row6_col3, #T_ae1c2_row7_col1, #T_ae1c2_row7_col2, #T_ae1c2_row7_col3, #T_ae1c2_row8_col1, #T_ae1c2_row8_col2, #T_ae1c2_row8_col3, #T_ae1c2_row9_col1, #T_ae1c2_row9_col2, #T_ae1c2_row9_col3, #T_ae1c2_row10_col1, #T_ae1c2_row10_col2, #T_ae1c2_row10_col3, #T_ae1c2_row11_col1, #T_ae1c2_row11_col2, #T_ae1c2_row11_col3, #T_ae1c2_row12_col1, #T_ae1c2_row12_col2, #T_ae1c2_row12_col3, #T_ae1c2_row13_col1, #T_ae1c2_row13_col2, #T_ae1c2_row13_col3, #T_ae1c2_row14_col1, #T_ae1c2_row14_col2, #T_ae1c2_row14_col3, #T_ae1c2_row15_col1, #T_ae1c2_row15_col2, #T_ae1c2_row15_col3, #T_ae1c2_row16_col1, #T_ae1c2_row16_col2, #T_ae1c2_row16_col3, #T_ae1c2_row17_col1, #T_ae1c2_row17_col2, #T_ae1c2_row17_col3, #T_ae1c2_row18_col1, #T_ae1c2_row18_col2, #T_ae1c2_row18_col3, #T_ae1c2_row19_col1, #T_ae1c2_row19_col2, #T_ae1c2_row19_col3, #T_ae1c2_row20_col1, #T_ae1c2_row20_col2, #T_ae1c2_row20_col3, #T_ae1c2_row21_col1, #T_ae1c2_row21_col2, #T_ae1c2_row21_col3, #T_ae1c2_row22_col1, #T_ae1c2_row22_col2, #T_ae1c2_row22_col3, #T_ae1c2_row23_col1, #T_ae1c2_row23_col2, #T_ae1c2_row23_col3, #T_ae1c2_row24_col1, #T_ae1c2_row24_col2, #T_ae1c2_row24_col3, #T_ae1c2_row25_col1, #T_ae1c2_row25_col2, #T_ae1c2_row25_col3, #T_ae1c2_row26_col1, #T_ae1c2_row26_col2, #T_ae1c2_row26_col3, #T_ae1c2_row27_col1, #T_ae1c2_row27_col2, #T_ae1c2_row27_col3, #T_ae1c2_row28_col1, #T_ae1c2_row28_col2, #T_ae1c2_row28_col3, #T_ae1c2_row29_col1, #T_ae1c2_row29_col2, #T_ae1c2_row29_col3, #T_ae1c2_row30_col1, #T_ae1c2_row30_col2, #T_ae1c2_row30_col3, #T_ae1c2_row31_col1, #T_ae1c2_row31_col2, #T_ae1c2_row31_col3, #T_ae1c2_row32_col1, #T_ae1c2_row32_col2, #T_ae1c2_row32_col3, #T_ae1c2_row33_col1, #T_ae1c2_row33_col2, #T_ae1c2_row33_col3, #T_ae1c2_row34_col1, #T_ae1c2_row34_col2, #T_ae1c2_row34_col3, #T_ae1c2_row35_col1, #T_ae1c2_row35_col2, #T_ae1c2_row35_col3, #T_ae1c2_row36_col1, #T_ae1c2_row36_col2, #T_ae1c2_row36_col3, #T_ae1c2_row37_col1, #T_ae1c2_row37_col2, #T_ae1c2_row37_col3, #T_ae1c2_row38_col1, #T_ae1c2_row38_col2, #T_ae1c2_row38_col3, #T_ae1c2_row39_col1, #T_ae1c2_row39_col2, #T_ae1c2_row39_col3, #T_ae1c2_row40_col1, #T_ae1c2_row40_col2, #T_ae1c2_row40_col3, #T_ae1c2_row41_col1, #T_ae1c2_row41_col2, #T_ae1c2_row41_col3, #T_ae1c2_row42_col1, #T_ae1c2_row42_col2, #T_ae1c2_row42_col3, #T_ae1c2_row43_col1, #T_ae1c2_row43_col2, #T_ae1c2_row43_col3, #T_ae1c2_row44_col1, #T_ae1c2_row44_col2, #T_ae1c2_row44_col3, #T_ae1c2_row45_col1, #T_ae1c2_row45_col2, #T_ae1c2_row45_col3, #T_ae1c2_row46_col1, #T_ae1c2_row46_col2, #T_ae1c2_row46_col3, #T_ae1c2_row47_col1, #T_ae1c2_row47_col2, #T_ae1c2_row47_col3, #T_ae1c2_row48_col1, #T_ae1c2_row48_col2, #T_ae1c2_row48_col3, #T_ae1c2_row49_col1, #T_ae1c2_row49_col2, #T_ae1c2_row49_col3, #T_ae1c2_row50_col1, #T_ae1c2_row50_col2, #T_ae1c2_row50_col3, #T_ae1c2_row51_col1, #T_ae1c2_row51_col2, #T_ae1c2_row51_col3, #T_ae1c2_row52_col1, #T_ae1c2_row52_col2, #T_ae1c2_row52_col3, #T_ae1c2_row53_col1, #T_ae1c2_row53_col2, #T_ae1c2_row53_col3, #T_ae1c2_row54_col1, #T_ae1c2_row54_col2, #T_ae1c2_row54_col3, #T_ae1c2_row55_col1, #T_ae1c2_row55_col2, #T_ae1c2_row55_col3, #T_ae1c2_row56_col1, #T_ae1c2_row56_col2, #T_ae1c2_row56_col3, #T_ae1c2_row57_col1, #T_ae1c2_row57_col2, #T_ae1c2_row57_col3, #T_ae1c2_row58_col1, #T_ae1c2_row58_col2, #T_ae1c2_row58_col3, #T_ae1c2_row59_col1, #T_ae1c2_row59_col2, #T_ae1c2_row59_col3, #T_ae1c2_row60_col1, #T_ae1c2_row60_col2, #T_ae1c2_row60_col3, #T_ae1c2_row61_col1, #T_ae1c2_row61_col2, #T_ae1c2_row61_col3, #T_ae1c2_row62_col1, #T_ae1c2_row62_col2, #T_ae1c2_row62_col3, #T_ae1c2_row63_col1, #T_ae1c2_row63_col2, #T_ae1c2_row63_col3 ...

# %% [markdown]
# ## Analyze Book

# %%
ANALYZER = Analyzer(200)

ANALYZER.load_data(MORPHGNT_CSV, LEXEMES_CSV, MOUNCE_TXT)

book_report = ANALYZER.get_book_report(1, 1, add_nt_word_index=True)

report_styler = book_report.get_styler()
report_styler
# Out:
# <style type="text/css">
# #T_5b97f th {
#   text-align: left;
# }
# #T_5b97f_row0_col2, #T_5b97f_row0_col3, #T_5b97f_row0_col4, #T_5b97f_row1_col2, #T_5b97f_row1_col3, #T_5b97f_row1_col4, #T_5b97f_row2_col2, #T_5b97f_row2_col3, #T_5b97f_row2_col4, #T_5b97f_row3_col2, #T_5b97f_row3_col3, #T_5b97f_row3_col4, #T_5b97f_row4_col2, #T_5b97f_row4_col3, #T_5b97f_row4_col4, #T_5b97f_row5_col2, #T_5b97f_row5_col3, #T_5b97f_row5_col4, #T_5b97f_row6_col2, #T_5b97f_row6_col3, #T_5b97f_row6_col4, #T_5b97f_row7_col2, #T_5b97f_row7_col3, #T_5b97f_row7_col4, #T_5b97f_row8_col2, #T_5b97f_row8_col3, #T_5b97f_row8_col4, #T_5b97f_row9_col2, #T_5b97f_row9_col3, #T_5b97f_row9_col4, #T_5b97f_row10_col2, #T_5b97f_row10_col3, #T_5b97f_row10_col4, #T_5b97f_row11_col2, #T_5b97f_row11_col3, #T_5b97f_row11_col4, #T_5b97f_row12_col2, #T_5b97f_row12_col3, #T_5b97f_row12_col4, #T_5b97f_row13_col2, #T_5b97f_row13_col3, #T_5b97f_row13_col4, #T_5b97f_row14_col2, #T_5b97f_row14_col3, #T_5b97f_row14_col4, #T_5b97f_row15_col2, #T_5b97f_row15_col3, #T_5b97f_row15_col4, #T_5b97f_row16_col2, #T_5b97f_row16_col3, #T_5b97f_row16_col4, #T_5b97f_row17_col2, #T_5b97f_row17_col3, #T_5b97f_row17_col4, #T_5b97f_row18_col2, #T_5b97f_row18_col3, #T_5b97f_row18_col4, #T_5b97f_row19_col2, #T_5b97f_row19_col3, #T_5b97f_row19_col4, #T_5b97f_row20_col2, #T_5b97f_row20_col3, #T_5b97f_row20_col4, #T_5b97f_row21_col2, #T_5b97f_row21_col3, #T_5b97f_row21_col4, #T_5b97f_row22_col2, #T_5b97f_row22_col3, #T_5b97f_row22_col4, #T_5b97f_row23_col2, #T_5b97f_row23_col3, #T_5b97f_row23_col4, #T_5b97f_row24_col2, #T_5b97f_row24_col3, #T_5b97f_row24_col4, #T_5b97f_row25_col2, #T_5b97f_row25_col3, #T_5b97f_row25_col4, #T_5b97f_row26_col2, #T_5b97f_row26_col3, #T_5b97f_row26_col4, #T_5b97f_row27_col2, #T_5b97f_row27_col3, #T_5b97f_row27_col4, #T_5b97f_row28_col2, #T_5b97f_row28_col3, #T_5b97f_row28_col4, #T_5b97f_row29_col2, #T_5b97f_row29_col3, #T_5b97f_row29_col4, #T_5b97f_row30_col2, #T_5b97f_row30_col3, #T_5b97f_row30_col4, #T_5b97f_row31_col2, #T_5b97f_row31_col3, #T_5b97f_row31_col4, #T_5b97f_row32_col2, #T_5b97f_row32_col3, #T_5b97f_row32_col4, #T_5b97f_row33_col2, #T_5b97f_row33_col3, #T_5b97f_row33_col4, #T_5b97f_row34_col2, #T_5b97f_row34_col3, #T_5b97f_row34_col4, #T_5b97f_row35_col2, #T_5b97f_row35_col3, #T_5b97f_row35_col4, #T_5b97f_row36_col2, #T_5b97f_row36_col3, #T_5b97f_row36_col4, #T_5b97f_row37_col2, #T_5b97f_row37_col3, #T_5b97f_row37_col4, #T_5b97f_row38_col2, #T_5b97f_row38_col3, #T_5b97f_row38_col4, #T_5b97f_row39_col2, #T_5b97f_row39_col3, #T_5b97f_row39_col4, #T_5b97f_row40_col2, #T_5b97f_row40_col3, #T_5b97f_row40_col4, #T_5b97f_row41_col2, #T_5b97f_row41_col3, #T_5b97f_row41_col4, #T_5b97f_row42_col2, #T_5b97f_row42_col3, #T_5b97f_row42_col4, #T_5b97f_row43_col2, #T_5b97f_row43_col3, #T_5b97f_row43_col4, #T_5b97f_row44_col2, #T_5b97f_row44_col3, #T_5b97f_row44_col4, #T_5b97f_row45_col2, #T_5b97f_row45_col3, #T_5b97f_row45_col4, #T_5b97f_row46_col2, #T_5b97f_row46_col3, #T_5b97f_row46_col4, #T_5b97f_row47_col2, #T_5b97f_row47_col3, #T_5b97f_row47_col4, #T_5b97f_row48_col2, #T_5b97f_row48_col3, #T_5b97f_row48_col4, #T_5b97f_row49_col2, #T_5b97f_row49_col3, #T_5b97f_row49_col4, #T_5b97f_row50_col2, #T_5b97f_row50_col3, #T_5b97f_row50_col4, #T_5b97f_row51_col2, #T_5b97f_row51_col3, #T_5b97f_row51_col4, #T_5b97f_row52_col2, #T_5b97f_row52_col3, #T_5b97f_row52_col4, #T_5b97f_row53_col2, #T_5b97f_row53_col3, #T_5b97f_row53_col4, #T_5b97f_row54_col2, #T_5b97f_row54_col3, #T_5b97f_row54_col4, #T_5b97f_row55_col2, #T_5b97f_row55_col3, #T_5b97f_row55_col4, #T_5b97f_row56_col2, #T_5b97f_row56_col3, #T_5b97f_row56_col4, #T_5b97f_row57_col2, #T_5b97f_row57_col3, #T_5b97f_row57_col4, #T_5b97f_row58_col2, #T_5b97f_row58_col3, #T_5b97f_row58_col4, #T_5b97f_row59_col2, #T_5b97f_row59_col3, #T_5b97f_row59_col4, #T_5b97f_row60_col2, #T_5b97f_row60_col3, #T_5b97f_row60_col4, #T_5b97f_row61_col2, #T_5b97f_row61_col3, #T_5b97f_row61_col4, #T_5b97f_row62_col2, #T_5b97f_row62_col3, #T_5b97f_row62_col4, #T_5b97f_row63_col2, #T_5b97f_row63_col3, #T_5b97f_row63_col4 ...

# %% [markdown]
# ## Create Usage Reports

# %%
from pathlib import Path
import unicodedata
import biblesdk.constants as bc
from biblesdk.books import BOOKS


def strip_diacritics(series):
    return series.apply(lambda value: unicodedata.normalize("NFKD", value))


ANALYZER = Analyzer(200)
ANALYZER.load_data(MORPHGNT_CSV, LEXEMES_CSV, MOUNCE_TXT)
Path("reports").mkdir(exist_ok=True)

# Create New Testament summary report.
#
new_testament_report = ANALYZER.get_new_testament_report()

report_html = f"<h2>New Testament</h2>"
for property_name, property_value in new_testament_report.properties.items():
    report_html += f"<p>{property_name}: {property_value}"

report_html += "<h3>By Ranking</h3>"
new_testament_report_styler = new_testament_report.get_styler()
report_html += new_testament_report_styler.to_html()

report_html += "<h3>By Part of Speech</h3>"
new_testament_report.df.sort_values(
    [bc.PART_OF_SPEECH, bc.LEXICAL_ENTRY], inplace=True, key=strip_diacritics
)
new_testament_report_styler = new_testament_report.get_styler()
report_html += new_testament_report_styler.to_html()

with open("reports/words_00_new_testament.html", "w", encoding="utf-8") as file:
    file.write(report_html)

# Create book detail reports.
#
for book_number in BOOKS:
    book_name = BOOKS[book_number]
    book_report = ANALYZER.get_book_report(book_number, add_nt_word_index=True)

    report_html = f"<h2>{book_name}</h2>"
    for property_name, property_value in book_report.properties.items():
        report_html += f"<p>{property_name}: {property_value}"

    report_html += "<h3>By Ranking</h3>"
    report_styler = book_report.get_styler()
    report_html += report_styler.to_html()

    report_html += "<h3>New Words</h3>"
    book_report.df.sort_values(
        [bc.PART_OF_SPEECH, bc.LEXICAL_ENTRY], inplace=True, key=strip_diacritics
    )
    book_report.df.drop(
        book_report.df[book_report.df[bc.NEW_TESTAMENT_WORD_INDEX] <= 200].index,
        inplace=True,
    )
    report_styler = book_report.get_styler(highlight_nt_rank=False)
    report_html += report_styler.to_html()

    with open(
        f"reports/words_{book_number:02d}_{book_name}.html", "w", encoding="utf-8"
    ) as file:
        file.write(report_html)
