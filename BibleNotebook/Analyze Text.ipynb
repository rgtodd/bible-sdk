# %% [markdown]
# # Word Usage
#
# Determines New Testament word usage.
#
# Creates word usage reports in `/reports` folder.
#
# ## Imports and Parameters

# %%
from pathlib import Path
import unicodedata

import biblesdk.columns as bc
from biblesdk.report import Report
from biblesdk.analyzer import Analyzer
from biblesdk.books import BOOKS

LEXEMES_CSV = "lexemes.csv"
MORPHGNT_CSV = "morphgnt.csv"
MOUNCE_TXT = "../BibleCore/resources/mounce.txt"

# %% [markdown]
# ## Analyze New Testament
#
# Creates a New Testament report.

# %%
ANALYZER = Analyzer(10)

ANALYZER.load_data(MORPHGNT_CSV, LEXEMES_CSV, MOUNCE_TXT)

new_testament_report = ANALYZER.get_new_testament_report()

new_testament_report_styler = new_testament_report.get_styler()
new_testament_report_styler
# Out:
# <style type="text/css">
# #T_75f05 th {
#   text-align: left;
# }
# #T_75f05_row0_col1, #T_75f05_row0_col2, #T_75f05_row0_col3, #T_75f05_row1_col1, #T_75f05_row1_col2, #T_75f05_row1_col3, #T_75f05_row2_col1, #T_75f05_row2_col2, #T_75f05_row2_col3, #T_75f05_row3_col1, #T_75f05_row3_col2, #T_75f05_row3_col3, #T_75f05_row4_col1, #T_75f05_row4_col2, #T_75f05_row4_col3, #T_75f05_row5_col1, #T_75f05_row5_col2, #T_75f05_row5_col3, #T_75f05_row6_col1, #T_75f05_row6_col2, #T_75f05_row6_col3, #T_75f05_row7_col1, #T_75f05_row7_col2, #T_75f05_row7_col3, #T_75f05_row8_col1, #T_75f05_row8_col2, #T_75f05_row8_col3, #T_75f05_row9_col1, #T_75f05_row9_col2, #T_75f05_row9_col3 {
#   text-align: left;
# }
# #T_75f05_row0_col4, #T_75f05_row0_col5, #T_75f05_row0_col6, #T_75f05_row0_col7, #T_75f05_row1_col4, #T_75f05_row1_col5, #T_75f05_row1_col6, #T_75f05_row1_col7, #T_75f05_row2_col4, #T_75f05_row2_col5, #T_75f05_row2_col6, #T_75f05_row2_col7, #T_75f05_row3_col4, #T_75f05_row3_col5, #T_75f05_row3_col6, #T_75f05_row3_col7, #T_75f05_row4_col4, #T_75f05_row4_col5, #T_75f05_row4_col6, #T_75f05_row4_col7, #T_75f05_row5_col4, #T_75f05_row5_col5, #T_75f05_row5_col6, #T_75f05_row5_col7, #T_75f05_row6_col4, #T_75f05_row6_col5, #T_75f05_row6_col6, #T_75f05_row6_col7, #T_75f05_row7_col4, #T_75f05_row7_col5, #T_75f05_row7_col6, #T_75f05_row7_col7, #T_75f05_row8_col4, #T_75f05_row8_col5, #T_75f05_row8_col6, #T_75f05_row8_col7, #T_75f05_row9_col4, #T_75f05_row9_col5, #T_75f05_row9_col6, #T_75f05_row9_col7 {
#   text-align: right;
# }
# </style>
# <table id="T_75f05">
#   <thead>
#     <tr>
#       <th id="T_75f05_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_75f05_level0_col1" class="col_heading level0 col1" >Part of Speech</th>
#       <th id="T_75f05_level0_col2" class="col_heading level0 col2" >Lexical Entry</th>
#       <th id="T_75f05_level0_col3" class="col_heading level0 col3" >Gloss</th>
#       <th id="T_75f05_level0_col4" class="col_heading level0 col4" >Strongs</th>
#       <th id="T_75f05_level0_col5" class="col_heading level0 col5" >GK</th>
#       <th id="T_75f05_level0_col6" class="col_heading level0 col6" >Mounce</th>
#       <th id="T_75f05_level0_col7" class="col_heading level0 col7" >Word Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_75f05_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_75f05_row0_col1" class="data row0 col1" >Definite Article</td>
#       <td id="T_75f05_row0_col2" class="data row0 col2" >ὁ, ἡ, τό</td>
#       <td id="T_75f05_row0_col3" class="data row0 col3" >the</td>
#       <td id="T_75f05_row0_col4" class="data row0 col4" >3588</td>
#       <td id="T_75f05_row0_col5" class="data row0 col5" >3836</td>
#       <td id="T_75f05_row0_col6" class="data row0 col6" >6</td>
#       <td id="T_75f05_row0_col7" class="data row0 col7" >19,769</td>
#     </tr>
#     <tr>
#       <td id="T_75f05_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_75f05_row1_col1" class="data row1 col1" >Conjunction</td>
#       <td id="T_75f05_row1_col2" class="data row1 col2" >καί</td>
#       <td id="T_75f05_row1_col3" class="data row1 col3" >and, even, also, namely</td>
#       <td id="T_75f05_row1_col4" class="data row1 col4" >2532</td>
#       <td id="T_75f05_row1_col5" class="data row1 col5" >2779</td>
#       <td id="T_75f05_row1_col6" class="data row1 col6" >4</td>
#       <td id="T_75f05_row1_col7" class="data row1 col7" >8,973</td>
#     </tr>
#     <tr>
#       <td id="T_75f05_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_75f05_row2_col1" class="data row2 col1" >Pronoun - Personal</td>
#       <td id="T_75f05_row2_col2" class="data row2 col2" >αὐτός, αὐτή, αὐτό</td>
#       <td id="T_75f05_row2_col3" class="data row2 col3" >he, she, it, they, them, same</td>
#       <td id="T_75f05_row2_col4" class="data row2 col4" >0846</td>
#       <td id="T_75f05_row2_col5" class="data row2 col5" >0899</td>
#       <td id="T_75f05_row2_col6" class="data row2 col6" >6</td>
#       <td id="T_75f05_row2_col7" class="data row2 col7" >5,546</td>
#     </tr>
#     <tr>
#       <td id="T_75f05_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_75f05_row3_col1" class="data row3 col1" >Pronoun - Personal</td>
#       <td id="T_75f05_row3_col2" class="data row3 col2" >σύ, σοῦ, σοί, σέ</td>
#       <td id="T_75f05_row3_col3" class="data row3 col3" >you</td>
#       <td id="T_75f05_row3_col4" class="data row3 col4" >4771</td>
#       <td id="T_75f05_row3_col5" class="data row3 col5" >5148</td>
#       <td id="T_75f05_row3_col6" class="data row3 col6" >7</td>
#       <td id="T_75f05_row3_col7" class="data row3 col7" >2,894</td>
#     </tr>
#     <tr>
#       <td id="T_75f05_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_75f05_row4_col1" class="data row4 col1" >Conjunction</td>
#       <td id="T_75f05_row4_col2" class="data row4 col2" >δέ</td>
#       <td id="T_75f05_row4_col3" class="data row4 col3" >but, on the other hand, and</td>
#       <td id="T_75f05_row4_col4" class="data row4 col4" >1161</td>
#       <td id="T_75f05_row4_col5" class="data row4 col5" >1254</td>
#       <td id="T_75f05_row4_col6" class="data row4 col6" >6</td>
#       <td id="T_75f05_row4_col7" class="data row4 col7" >2,766</td>
#     </tr>
#     <tr>
#       <td id="T_75f05_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_75f05_row5_col1" class="data row5 col1" >Preposition</td>
#       <td id="T_75f05_row5_col2" class="data row5 col2" >ἐν</td>
#       <td id="T_75f05_row5_col3" class="data row5 col3" >in, on, among (dat)</td>
#       <td id="T_75f05_row5_col4" class="data row5 col4" >1722</td>
#       <td id="T_75f05_row5_col5" class="data row5 col5" >1877</td>
#       <td id="T_75f05_row5_col6" class="data row5 col6" >6</td>
#       <td id="T_75f05_row5_col7" class="data row5 col7" >2,733</td>
#     </tr>
#     <tr>
#       <td id="T_75f05_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_75f05_row6_col1" class="data row6 col1" >Pronoun - Personal</td>
#       <td id="T_75f05_row6_col2" class="data row6 col2" >ἐγώ</td>
#       <td id="T_75f05_row6_col3" class="data row6 col3" >I</td>
#       <td id="T_75f05_row6_col4" class="data row6 col4" >1473</td>
#       <td id="T_75f05_row6_col5" class="data row6 col5" >1609</td>
#       <td id="T_75f05_row6_col6" class="data row6 col6" >4</td>
#       <td id="T_75f05_row6_col7" class="data row6 col7" >2,572</td>
#     </tr>
#     <tr>
#       <td id="T_75f05_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_75f05_row7_col1" class="data row7 col1" >Verb</td>
#       <td id="T_75f05_row7_col2" class="data row7 col2" >εἰμί</td>
#       <td id="T_75f05_row7_col3" class="data row7 col3" >I am, exist</td>
#       <td id="T_75f05_row7_col4" class="data row7 col4" >1510</td>
#       <td id="T_75f05_row7_col5" class="data row7 col5" >1639</td>
#       <td id="T_75f05_row7_col6" class="data row7 col6" >8</td>
#       <td id="T_75f05_row7_col7" class="data row7 col7" >2,456</td>
#     </tr>
#     <tr>
#       <td id="T_75f05_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_75f05_row8_col1" class="data row8 col1" >Verb</td>
#       <td id="T_75f05_row8_col2" class="data row8 col2" >λέγω</td>
#       <td id="T_75f05_row8_col3" class="data row8 col3" >I say, speak</td>
#       <td id="T_75f05_row8_col4" class="data row8 col4" >2036</td>
#       <td id="T_75f05_row8_col5" class="data row8 col5" >3306</td>
#       <td id="T_75f05_row8_col6" class="data row8 col6" >7,8,8,16</td>
#       <td id="T_75f05_row8_col7" class="data row8 col7" >2,345</td>
#     </tr>
#     <tr>
#       <td id="T_75f05_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_75f05_row9_col1" class="data row9 col1" >Preposition</td>
#       <td id="T_75f05_row9_col2" class="data row9 col2" >εἰς</td>
#       <td id="T_75f05_row9_col3" class="data row9 col3" >into, in, among, till, for (acc)</td>
#       <td id="T_75f05_row9_col4" class="data row9 col4" >1519</td>
#       <td id="T_75f05_row9_col5" class="data row9 col5" >1650</td>
#       <td id="T_75f05_row9_col6" class="data row9 col6" >7</td>
#       <td id="T_75f05_row9_col7" class="data row9 col7" >1,754</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Analyze Book

# %%
ANALYZER = Analyzer(10)

ANALYZER.load_data(MORPHGNT_CSV, LEXEMES_CSV, MOUNCE_TXT)

book_report = ANALYZER.get_book_report(1, 1, add_nt_word_index=True)

report_styler = book_report.get_styler()
report_styler
# Out:
# <style type="text/css">
# #T_38ddf th {
#   text-align: left;
# }
# #T_38ddf_row0_col2, #T_38ddf_row0_col3, #T_38ddf_row0_col4, #T_38ddf_row1_col2, #T_38ddf_row1_col3, #T_38ddf_row1_col4, #T_38ddf_row2_col2, #T_38ddf_row2_col3, #T_38ddf_row2_col4, #T_38ddf_row3_col2, #T_38ddf_row3_col3, #T_38ddf_row3_col4, #T_38ddf_row4_col2, #T_38ddf_row4_col3, #T_38ddf_row4_col4, #T_38ddf_row5_col2, #T_38ddf_row5_col3, #T_38ddf_row5_col4, #T_38ddf_row6_col2, #T_38ddf_row6_col3, #T_38ddf_row6_col4, #T_38ddf_row7_col2, #T_38ddf_row7_col3, #T_38ddf_row7_col4, #T_38ddf_row8_col2, #T_38ddf_row8_col3, #T_38ddf_row8_col4, #T_38ddf_row9_col2, #T_38ddf_row9_col3, #T_38ddf_row9_col4, #T_38ddf_row10_col2, #T_38ddf_row10_col3, #T_38ddf_row10_col4, #T_38ddf_row11_col2, #T_38ddf_row11_col3, #T_38ddf_row11_col4, #T_38ddf_row12_col2, #T_38ddf_row12_col3, #T_38ddf_row12_col4, #T_38ddf_row13_col2, #T_38ddf_row13_col3, #T_38ddf_row13_col4, #T_38ddf_row14_col2, #T_38ddf_row14_col3, #T_38ddf_row14_col4 {
#   text-align: left;
# }
# #T_38ddf_row0_col5, #T_38ddf_row0_col6, #T_38ddf_row0_col7, #T_38ddf_row0_col8, #T_38ddf_row1_col5, #T_38ddf_row1_col6, #T_38ddf_row1_col7, #T_38ddf_row1_col8, #T_38ddf_row2_col5, #T_38ddf_row2_col6, #T_38ddf_row2_col7, #T_38ddf_row2_col8, #T_38ddf_row3_col5, #T_38ddf_row3_col6, #T_38ddf_row3_col7, #T_38ddf_row3_col8, #T_38ddf_row4_col5, #T_38ddf_row4_col6, #T_38ddf_row4_col7, #T_38ddf_row4_col8, #T_38ddf_row5_col5, #T_38ddf_row5_col6, #T_38ddf_row5_col7, #T_38ddf_row5_col8, #T_38ddf_row6_col5, #T_38ddf_row6_col6, #T_38ddf_row6_col7, #T_38ddf_row6_col8, #T_38ddf_row7_col5, #T_38ddf_row7_col6, #T_38ddf_row7_col7, #T_38ddf_row7_col8, #T_38ddf_row8_col5, #T_38ddf_row8_col6, #T_38ddf_row8_col7, #T_38ddf_row8_col8, #T_38ddf_row9_col5, #T_38ddf_row9_col6, #T_38ddf_row9_col7, #T_38ddf_row9_col8, #T_38ddf_row10_col5, #T_38ddf_row10_col6, #T_38ddf_row10_col7, #T_38ddf_row10_col8, #T_38ddf_row11_col5, #T_38ddf_row11_col6, #T_38ddf_row11_col7, #T_38ddf_row11_col8, #T_38ddf_row12_col5, #T_38ddf_row12_col6, #T_38ddf_row12_col7, #T_38ddf_row12_col8, #T_38ddf_row13_col5, #T_38ddf_row13_col6, #T_38ddf_row13_col7, #T_38ddf_row13_col8, #T_38ddf_row14_col5, #T_38ddf_row14_col6, #T_38ddf_row14_col7, #T_38ddf_row14_col8 {
#   text-align: right;
# }
# #T_38ddf_row2_col0, #T_38ddf_row5_col0, #T_38ddf_row6_col0, #T_38ddf_row7_col0, #T_38ddf_row8_col0, #T_38ddf_row9_col0 {
#   background-color: LightGreen;
# }
# </style>
# <table id="T_38ddf">
#   <thead>
#     <tr>
#       <th id="T_38ddf_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_38ddf_level0_col1" class="col_heading level0 col1" >NT Rank</th>
#       <th id="T_38ddf_level0_col2" class="col_heading level0 col2" >Part of Speech</th>
#       <th id="T_38ddf_level0_col3" class="col_heading level0 col3" >Lexical Entry</th>
#       <th id="T_38ddf_level0_col4" class="col_heading level0 col4" >Gloss</th>
#       <th id="T_38ddf_level0_col5" class="col_heading level0 col5" >Strongs</th>
#       <th id="T_38ddf_level0_col6" class="col_heading level0 col6" >GK</th>
#       <th id="T_38ddf_level0_col7" class="col_heading level0 col7" >Mounce</th>
#       <th id="T_38ddf_level0_col8" class="col_heading level0 col8" >Word Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38ddf_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_38ddf_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_38ddf_row0_col2" class="data row0 col2" >Definite Article</td>
#       <td id="T_38ddf_row0_col3" class="data row0 col3" >ὁ, ἡ, τό</td>
#       <td id="T_38ddf_row0_col4" class="data row0 col4" >the</td>
#       <td id="T_38ddf_row0_col5" class="data row0 col5" >3588</td>
#       <td id="T_38ddf_row0_col6" class="data row0 col6" >3836</td>
#       <td id="T_38ddf_row0_col7" class="data row0 col7" >6</td>
#       <td id="T_38ddf_row0_col8" class="data row0 col8" >76</td>
#     </tr>
#     <tr>
#       <td id="T_38ddf_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_38ddf_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_38ddf_row1_col2" class="data row1 col2" >Conjunction</td>
#       <td id="T_38ddf_row1_col3" class="data row1 col3" >δέ</td>
#       <td id="T_38ddf_row1_col4" class="data row1 col4" >but, on the other hand, and</td>
#       <td id="T_38ddf_row1_col5" class="data row1 col5" >1161</td>
#       <td id="T_38ddf_row1_col6" class="data row1 col6" >1254</td>
#       <td id="T_38ddf_row1_col7" class="data row1 col7" >6</td>
#       <td id="T_38ddf_row1_col8" class="data row1 col8" >44</td>
#     </tr>
#     <tr>
#       <td id="T_38ddf_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_38ddf_row2_col1" class="data row2 col1" >175</td>
#       <td id="T_38ddf_row2_col2" class="data row2 col2" >Verb</td>
#       <td id="T_38ddf_row2_col3" class="data row2 col3" >γεννάω</td>
#       <td id="T_38ddf_row2_col4" class="data row2 col4" >I beget, bring forth, give birth to</td>
#       <td id="T_38ddf_row2_col5" class="data row2 col5" >1080</td>
#       <td id="T_38ddf_row2_col6" class="data row2 col6" >1164</td>
#       <td id="T_38ddf_row2_col7" class="data row2 col7" >19</td>
#       <td id="T_38ddf_row2_col8" class="data row2 col8" >41</td>
#     </tr>
#     <tr>
#       <td id="T_38ddf_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_38ddf_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_38ddf_row3_col2" class="data row3 col2" >Pronoun - Personal</td>
#       <td id="T_38ddf_row3_col3" class="data row3 col3" >αὐτός, αὐτή, αὐτό</td>
#       <td id="T_38ddf_row3_col4" class="data row3 col4" >he, she, it, they, them, same</td>
#       <td id="T_38ddf_row3_col5" class="data row3 col5" >0846</td>
#       <td id="T_38ddf_row3_col6" class="data row3 col6" >0899</td>
#       <td id="T_38ddf_row3_col7" class="data row3 col7" >6</td>
#       <td id="T_38ddf_row3_col8" class="data row3 col8" >19</td>
#     </tr>
#     <tr>
#       <td id="T_38ddf_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_38ddf_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_38ddf_row4_col2" class="data row4 col2" >Conjunction</td>
#       <td id="T_38ddf_row4_col3" class="data row4 col3" >καί</td>
#       <td id="T_38ddf_row4_col4" class="data row4 col4" >and, even, also, namely</td>
#       <td id="T_38ddf_row4_col5" class="data row4 col5" >2532</td>
#       <td id="T_38ddf_row4_col6" class="data row4 col6" >2779</td>
#       <td id="T_38ddf_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_38ddf_row4_col8" class="data row4 col8" >12</td>
#     </tr>
#     <tr>
#       <td id="T_38ddf_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_38ddf_row5_col1" class="data row5 col1" >19</td>
#       <td id="T_38ddf_row5_col2" class="data row5 col2" >Preposition</td>
#       <td id="T_38ddf_row5_col3" class="data row5 col3" >ἐκ, ἐξ</td>
#       <td id="T_38ddf_row5_col4" class="data row5 col4" >from out, out from among, from (gen)</td>
#       <td id="T_38ddf_row5_col5" class="data row5 col5" >1537</td>
#       <td id="T_38ddf_row5_col6" class="data row5 col6" >1666</td>
#       <td id="T_38ddf_row5_col7" class="data row5 col7" >8</td>
#       <td id="T_38ddf_row5_col8" class="data row5 col8" >7</td>
#     </tr>
#     <tr>
#       <td id="T_38ddf_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_38ddf_row6_col1" class="data row6 col1" >275</td>
#       <td id="T_38ddf_row6_col2" class="data row6 col2" >Noun</td>
#       <td id="T_38ddf_row6_col3" class="data row6 col3" >Δαυίδ, ὁ</td>
#       <td id="T_38ddf_row6_col4" class="data row6 col4" >David</td>
#       <td id="T_38ddf_row6_col5" class="data row6 col5" >1138</td>
#       <td id="T_38ddf_row6_col6" class="data row6 col6" >1253</td>
#       <td id="T_38ddf_row6_col7" class="data row6 col7" >4</td>
#       <td id="T_38ddf_row6_col8" class="data row6 col8" >6</td>
#     </tr>
#     <tr>
#       <td id="T_38ddf_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_38ddf_row7_col1" class="data row7 col1" >48</td>
#       <td id="T_38ddf_row7_col2" class="data row7 col2" >Noun</td>
#       <td id="T_38ddf_row7_col3" class="data row7 col3" >υἱός, οῦ, ὁ</td>
#       <td id="T_38ddf_row7_col

# %% [markdown]
# ## Create Usage Reports

# %%
def strip_diacritics(series):
    return series.apply(lambda value: unicodedata.normalize("NFKD", value))


ANALYZER = Analyzer(200)
ANALYZER.load_data(MORPHGNT_CSV, LEXEMES_CSV, MOUNCE_TXT)
Path("reports").mkdir(exist_ok=True)

# Create New Testament summary report.
#
new_testament_report = ANALYZER.get_new_testament_report()

report_html = f"<h2>New Testament</h2>"
for property_name, property_value in new_testament_report.properties.items():
    report_html += f"<p>{property_name}: {property_value}"

report_html += "<h3>By Ranking</h3>"
new_testament_report_styler = new_testament_report.get_styler()
report_html += new_testament_report_styler.to_html()

report_html += "<h3>By Part of Speech</h3>"
new_testament_report.df.sort_values(
    [bc.PART_OF_SPEECH, bc.LEXICAL_ENTRY], inplace=True, key=strip_diacritics
)
new_testament_report_styler = new_testament_report.get_styler()
report_html += new_testament_report_styler.to_html()

with open("reports/words_00_new_testament.html", "w", encoding="utf-8") as file:
    file.write(report_html)

# Create book detail reports.
#
for book_number in BOOKS:
    book_name = BOOKS[book_number]
    book_report = ANALYZER.get_book_report(book_number, add_nt_word_index=True)

    report_html = f"<h2>{book_name}</h2>"
    for property_name, property_value in book_report.properties.items():
        report_html += f"<p>{property_name}: {property_value}"

    report_html += "<h3>By Ranking</h3>"
    report_styler = book_report.get_styler()
    report_html += report_styler.to_html()

    report_html += "<h3>New Words</h3>"
    book_report.df.sort_values(
        [bc.PART_OF_SPEECH, bc.LEXICAL_ENTRY], inplace=True, key=strip_diacritics
    )
    book_report.df.drop(
        book_report.df[book_report.df[bc.NEW_TESTAMENT_WORD_INDEX] <= 200].index,
        inplace=True,
    )
    report_styler = book_report.get_styler(highlight_nt_rank=False)
    report_html += report_styler.to_html()

    with open(
        f"reports/words_{book_number:02d}_{book_name}.html", "w", encoding="utf-8"
    ) as file:
        file.write(report_html)
