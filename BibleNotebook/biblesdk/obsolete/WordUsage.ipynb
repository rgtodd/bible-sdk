# %% [markdown]
# # Word Usage
#
# Determines word usage in book (Matthew).
#
# NOTE: Superceded by Word Usage.ipynb.
#
# ## Parse MorphGnt File into DataFrame (DF_WORDS)
#
# Loads the MorphGnt file for Matthew and filters words used in chapter 1.
#
# Saves the total word count as `TOTAL_WORD_COUNT`

# %%
import pandas as pd
from glob import glob
from os import path
from pprint import pprint

morphgnt_path = "../BibleCore/Resources/MorphGnt"

all_files = glob(path.join(morphgnt_path, "*.txt"))

DF_WORDS = pd.concat(
    (
        pd.read_csv(
            f,
            names=[
                "Scripture Reference",
                "Part of Speech",
                "Inflection",
                "Text",
                "Word",
                "Normalized Word",
                "Lemma",
            ],
            dtype={"Scripture Reference": "str"},
            sep="\\s+",
            index_col=False,
        )
        for f in all_files
    ),
    ignore_index=True,
)

DF_WORDS = DF_WORDS[(DF_WORDS['Scripture Reference'] >= '020101')&( DF_WORDS['Scripture Reference'] < '020201')]
TOTAL_WORD_COUNT = len(DF_WORDS)


print("===== DF_WORDS")
print(DF_WORDS.__class__.__name__)
print("-----")
pprint(vars(DF_WORDS))
print("-----")
pprint(DF_WORDS)

print("===== TOTAL_WORD_COUNT")
print(TOTAL_WORD_COUNT)
# Out:
# ===== DF_WORDS
# DataFrame
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': <weakref at 0x00000204CCC565C0; dead>,
#  '_item_cache': {},
#  '_mgr': BlockManager
# Items: Index(['Scripture Reference', 'Part of Speech', 'Inflection', 'Text', 'Word',
#        'Normalized Word', 'Lemma'],
#       dtype='object')
# Axis 1: Index([18329, 18330, 18331, 18332, 18333, 18334, 18335, 18336, 18337, 18338,
#        ...
#        19020, 19021, 19022, 19023, 19024, 19025, 19026, 19027, 19028, 19029],
#       dtype='int64', length=701)
# NumpyBlock: slice(0, 7, 1), 7 x 701, dtype: object}
# -----
#       Scripture Reference Part of Speech Inflection        Text        Word  \
# 18329              020101             N-   ----NSF-        Ἀρχὴ        Ἀρχὴ
# 18330              020101             RA   ----GSN-         τοῦ         τοῦ
# 18331              020101             N-   ----GSN-  εὐαγγελίου  εὐαγγελίου
# 18332              020101             N-   ----GSM-       Ἰησοῦ       Ἰησοῦ
# 18333              020101             N-   ----GSM-   ⸀χριστοῦ.     χριστοῦ
# ...                   ...            ...        ...         ...         ...
# 19025              020145             C-   --------         καὶ         καὶ
# 19026              020145             V-   3IMI-P--     ἤρχοντο     ἤρχοντο
# 19027              020145             P-   --------        πρὸς        πρὸς
# 19028              020145             RP   ----ASM-       αὐτὸν       αὐτὸν
# 19029              020145             D-   --------  ⸀πάντοθεν.    πάντοθεν
#
#       Normalized Word       Lemma
# 18329            ἀρχή        ἀρχή
# 18330             τοῦ           ὁ
# 18331      εὐαγγελίου  εὐαγγέλιον
# 18332           Ἰησοῦ      Ἰησοῦς
# 18333         Χριστοῦ     Χριστός
# ...               ...         ...
# 19025             καί         καί
# 19026         ἤρχοντο     ἔρχομαι
# 19027            πρός        πρός
# 19028           αὐτόν       αὐτός
# 19029        πάντοθεν    πάντοθεν
#
# [701 rows x 7 columns]
# ===== TOTAL_WORD_COUNT
# 701

# %% [markdown]
# ## Parse Lexemes File into DataFram (DF_LEXEMES)

# %%
import yaml

with open("../BibleCore/Resources/lexemes.yaml", "r", encoding="utf-8") as file:
    yaml_data = yaml.safe_load(file)

DF_LEXEMES = pd.DataFrame.from_dict(yaml_data, orient="index")
DF_LEXEMES.index.name = "Lemma"

print("===== DF_LEXEMES")
print(DF_LEXEMES.__class__.__name__)
print("-----")
pprint(vars(DF_LEXEMES))
print("-----")
pprint(DF_LEXEMES)
# Out:
# ===== DF_LEXEMES
# DataFrame
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': BlockManager
# Items: Index(['pos', 'full-citation-form', 'bdag-headword', 'danker-entry',
#        'dodson-entry', 'mounce-headword', 'strongs', 'gk', 'dodson-pos',
#        'gloss', 'mounce-morphcat'],
#       dtype='object')
# Axis 1: Index(['Ἀαρών', 'Ἀβαδδών', 'ἀβαρής', 'αββα', 'Ἅβελ', 'Ἀβιά', 'Ἀβιαθάρ',
#        'Ἀβιληνή', 'Ἀβιούδ', 'Ἀβραάμ',
#        ...
#        'ὡσεί', 'Ὡσηέ', 'ὥσπερ', 'ὡσπερεί', 'ὥστε', 'ὠτάριον', 'ὠτίον',
#        'ὠφέλεια', 'ὠφελέω', 'ὠφέλιμος'],
#       dtype='object', name='Lemma', length=5464)
# NumpyBlock: slice(0, 11, 1), 11 x 5464, dtype: object}
# -----
#          pos    full-citation-form bdag-headword          danker-entry  \
# Lemma
# Ἀαρών      N              Ἀαρών, ὁ         Ἀαρών              Ἀαρών, ὁ
# Ἀβαδδών    N            Ἀβαδδών, ὁ       Ἀβαδδών            Ἀβαδδών, ὁ
# ἀβαρής     A  ἀβαρής, ές, gen. οῦς        ἀβαρής  ἀβαρής, ές, gen. οῦς
# αββα       N                  αββα          ἀββα                  ἀββά
# Ἅβελ       N               Ἅβελ, ὁ          Ἅβελ               Ἅβελ, ὁ
# ...       ..                   ...           ...                   ...
# ὠτάριον    N       ὠτάριον, ου, τό       ὠτάριον       ὠτάριον, ου, τό
# ὠτίον      N         ὠτίον, ου, τό         ὠτίον         ὠτίον, ου, τό
# ὠφέλεια    N        ὠφέλεια, ας, ἡ       ὠφέλεια        ὠφέλεια, ας, ἡ
# ὠφελέω     V                   NaN        ὠφελέω                ὠφελέω
# ὠφέλιμος   A          ὠφέλιμος, ον      ὠφέλιμος          ὠφέλιμος, ον
#
#             dodson-entry mounce-headword strongs    gk dodson-pos  \
# Lemma
# Ἀαρών           Ἀαρών, ὁ           Ἀαρών       2     2      N-PRI
# Ἀβαδδών       Ἀβαδδών, ὁ         Ἀβαδδών       3     3      N-PRI
# ἀβαρής        ἀβαρής, ες          ἀβαρής       4     4          A
# αββα                Ἀββᾶ            ἀββά       5     5      N-PRI
# Ἅβελ             Ἄβελ, ὁ            Ἇβελ       6     6      N-PRI
# ...                  ...             ...     ...   ...        ...
# ὠτάριον              NaN         ὠτάριον     NaN  6064        NaN
# ὠτίον      ὠτίον, ου, τό           ὠτίον    5621  6065        N:N
# ὠφέλεια   ὠφέλεια, ας, ἡ         ὠφέλεια    5622  6066        N:F
# ὠφελέω            ὠφελέω          ὠφελέω    5623  6067          V
# ὠφέλιμος    ὠφέλιμος, ον        ὠφέλιμος    5624  6068          A
#
#                                    gloss mounce-morphcat
# Lemma
# Ἀαρών                              Aaron         n-3g(2)
# Ἀβαδδών                          Abaddon         n-3g(2)
# ἀβαρής                    not burdensome            a-4a
# αββα                              Father         n-3g(2)
# Ἅβελ                                Abel         n-3g(2)
# ...                                  ...             ...
# ὠτάριον                              NaN            n-2c
# ὠτίον                             an ear            n-2c
# ὠφέλεια    usefulness, profit, advantage            n-1a
# ὠφελέω          I help, benefit, do good        v-1d(2a)
# ὠφέλιμος  profitable, beneficial, useful            a-3a
#
# [5464 rows x 11 columns]

# %% [markdown]
# ## Extract Lemma Series from DataFrame (S_LEMMA)

# %%
S_LEMMA = DF_WORDS["Lemma"]

print("===== S_LEMMA")
print(S_LEMMA.__class__.__name__)
print("-----")
pprint(vars(S_LEMMA))
print("-----")
pprint(S_LEMMA)
# Out:
# ===== S_LEMMA
# Series
# -----
# {'_attrs': {},
#  '_cacher': ('Lemma',
#              <weakref at 0x00000204C8B4B420; to 'pandas.core.frame.DataFrame' at 0x00000204CB0408A0>),
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': <weakref at 0x00000204CCC565C0; dead>,
#  '_item_cache': {},
#  '_mgr': SingleBlockManager
# Items: Index([18329, 18330, 18331, 18332, 18333, 18334, 18335, 18336, 18337, 18338,
#        ...
#        19020, 19021, 19022, 19023, 19024, 19025, 19026, 19027, 19028, 19029],
#       dtype='int64', length=701)
# NumpyBlock: 701 dtype: object,
#  '_name': 'Lemma'}
# -----
# 18329          ἀρχή
# 18330             ὁ
# 18331    εὐαγγέλιον
# 18332        Ἰησοῦς
# 18333       Χριστός
#             ...
# 19025           καί
# 19026       ἔρχομαι
# 19027          πρός
# 19028         αὐτός
# 19029      πάντοθεν
# Name: Lemma, Length: 701, dtype: object

# %% [markdown]
# ## Group Lemmas by Value (GB_LEMMA_VALUES)

# %%
GB_LEMMA_VALUES = S_LEMMA.groupby(S_LEMMA.values)

print("===== GB_LEMMA_VALUES")
print(GB_LEMMA_VALUES.__class__.__name__)
print("-----")
pprint(vars(GB_LEMMA_VALUES))
print("-----")
pprint(GB_LEMMA_VALUES)
# Out:
# ===== GB_LEMMA_VALUES
# SeriesGroupBy
# -----
# {'_grouper': <pandas.core.groupby.ops.BaseGrouper object at 0x00000204CA5C9090>,
#  '_selection': None,
#  'as_index': True,
#  'axis': 0,
#  'dropna': True,
#  'exclusions': frozenset(),
#  'group_keys': True,
#  'keys': array(['ἀρχή', 'ὁ', 'εὐαγγέλιον', 'Ἰησοῦς', 'Χριστός', 'καθώς', 'γράφω',
#        'ἐν', 'ὁ', 'Ἠσαΐας', 'ὁ', 'προφήτης', 'ἰδού', 'ἀποστέλλω', 'ὁ',
#        'ἄγγελος', 'ἐγώ', 'πρό', 'πρόσωπον', 'σύ', 'ὅς', 'κατασκευάζω',
#        'ὁ', 'ὁδός', 'σύ', 'φωνή', 'βοάω', 'ἐν', 'ὁ', 'ἔρημος', 'ἑτοιμάζω',
#        'ὁ', 'ὁδός', 'κύριος', 'εὐθύς', 'ποιέω', 'ὁ', 'τρίβος', 'αὐτός',
#        'γίνομαι', 'Ἰωάννης', 'ὁ', 'βαπτίζω', 'ἐν', 'ὁ', 'ἔρημος',
#        'κηρύσσω', 'βάπτισμα', 'μετάνοια', 'εἰς', 'ἄφεσις', 'ἁμαρτία',
#        'καί', 'ἐκπορεύομαι', 'πρός', 'αὐτός', 'πᾶς', 'ὁ', 'Ἰουδαία',
#        'χώρα', 'καί', 'ὁ', 'Ἱεροσολυμίτης', 'πᾶς', 'καί', 'βαπτίζω',
#        'ὑπό', 'αὐτός', 'ἐν', 'ὁ', 'Ἰορδάνης', 'ποταμός', 'ἐξομολογέω',
#        'ὁ', 'ἁμαρτία', 'αὐτός', 'καί', 'εἰμί', 'ὁ', 'Ἰωάννης', 'ἐνδύω',
#        'θρίξ', 'κάμηλος', 'καί', 'ζώνη', 'δερμάτινος', 'περί', 'ὁ',
#        'ὀσφύς', 'αὐτός', 'καί', 'ἔσθω', 'ἀκρίς', 'καί', 'μέλι', 'ἄγριος',
#        'καί', 'κηρύσσω', 'λέγω', 'ἔρχομαι', 'ὁ', 'ἰσχυρός', 'ἐγώ',
#        'ὀπίσω', 'ἐγώ', 'ὅς', 'οὐ', 'εἰμί', 'ἱκανός', 'κύπτω', 'λύω', 'ὁ',
#        'ἱμάς', 'ὁ', 'ὑπόδημα', 'αὐτός', 'ἐγώ', 'βαπτίζω', 'σύ', 'ὕδωρ',
#        'αὐτός', 'δέ', 'βαπτίζω', 'σύ', 'ἐν', 'πνεῦμα', 'ἅγιος', 'καί',
#        'γίνομαι', 'ἐν', 'ἐκεῖνος', 'ὁ', 'ἡμέρα', 'ἔρχομαι', 'Ἰησοῦς',
#        'ἀπό', 'Ναζαρέτ', 'ὁ', 'Γαλιλαία', 'καί', 'βαπτίζω', 'εἰς', 'ὁ',
#        'Ἰορδάνης', 'ὑπό', 'Ἰωάννης', 'καί', 'εὐθύς', 'ἀναβαίνω', 'ἐκ',
#        'ὁ', 'ὕδωρ', 'ὁράω', 'σχίζω', 'ὁ', 'οὐρανός', 'καί', 'ὁ', 'πνεῦμα',
#        'ὡς', 'περιστερά', 'καταβαίνω', 'εἰς', 'αὐτός', 'καί', 'φωνή',
#        'γίνομαι', 'ἐκ', 'ὁ', 'οὐρανός', 'σύ', 'εἰμί', 'ὁ', 'υἱός', 'ἐγώ',
#        'ὁ', 'ἀγαπητός', 'ἐν', 'σύ', 'εὐδοκέω', 'καί', 'εὐθύς', 'ὁ',
#        'πνεῦμα', 'αὐτός', 'ἐκβάλλω', 'εἰς', 'ὁ', 'ἔρημος', 'καί', 'εἰμί',
#        'ἐν', 'ὁ', 'ἔρημος', 'τεσσεράκοντα', 'ἡμέρα', 'πειράζω', 'ὑπό',
#        'ὁ', 'Σατανᾶς', 'καί', 'εἰμί', 'μετά', 'ὁ', 'θηρίον', 'καί', 'ὁ',
#        'ἄγγελος', 'διακονέω', 'αὐτός', 'καί', 'μετά', 'ὁ', 'παραδίδωμι',
#        'ὁ', 'Ἰωάννης', 'ἔρχομαι', 'ὁ', 'Ἰησοῦς', 'εἰς', 'ὁ', 'Γαλιλαία',
#        'κηρύσσω', 'ὁ', 'εὐαγγέλιον', 'ὁ', 'θεός', 'καί', 'λέγω', 'ὅτι',
#        'πληρόω', 'ὁ', 'καιρός', 'καί', 'ἐγγίζω', 'ὁ', 'βασιλεία', 'ὁ',
#        'θεός', 'μετανοέω', 'καί', 'πιστεύω', 'ἐν', 'ὁ', 'εὐαγγέλιον',
#        'καί', 'παράγω', 'παρά', 'ὁ', 'θάλασσα', 'ὁ', 'Γαλιλαία', 'ὁράω',
#        'Σίμων', 'καί', 'Ἀνδρέας', 'ὁ', 'ἀδελφός', 'Σίμων', 'ἀμφιβάλλω',
#        'ἐν', 'ὁ', 'θάλασσα', 'εἰμί', 'γάρ', 'ἁλιεύς', 'καί', 'λέγω',
#        'αὐτός', 'ὁ', 'Ἰησοῦς', 'δεῦτε', 'ὀπίσω', 'ἐγώ', 'καί', 'ποιέω',
#        'σύ', 'γίνομαι', 'ἁλιεύς', 'ἄνθρωπος', 'καί', 'εὐθύς', 'ἀφίημι',
#        'ὁ', 'δίκτυον', 'ἀκολουθέω', 'αὐτός', 'καί', 'προβαίνω', 'ὀλίγος',
#        'ὁράω', 'Ἰάκωβος', 'ὁ', 'ὁ', 'Ζεβεδαῖος', 'καί', 'Ἰωάννης', 'ὁ',
#        'ἀδελφός', 'αὐτός', 'καί', 'αὐτός', 'ἐν', 'ὁ', 'πλοῖον',
#        'καταρτίζω', 'ὁ', 'δίκτυον', 'καί', 'εὐθύς', 'καλέω', 'αὐτός',
#        'καί', 'ἀφίημι', 'ὁ', 'πατήρ', 'αὐτός', 'Ζεβεδαῖος', 'ἐν', 'ὁ',
#        'πλοῖον', 'μετά', 'ὁ', 'μισθωτός', 'ἀπέρχομαι', 'ὀπίσω', 'αὐτός',
#        'καί', 'εἰσπορεύομαι', 'εἰς', 'Καφαρναούμ', 'καί', 'εὐθύς', 'ὁ',
#        'σάββατον', 'διδάσκω', 'εἰς', 'ὁ', 'συναγωγή', 'καί',
#        'ἐκπλήσσομαι', 'ἐπί', 'ὁ', 'διδαχή', 'αὐτός', 'εἰμί', 'γάρ',
#        'διδάσκω', 'αὐτός', 'ὡς', 'ἐξουσία', 'ἔχω', 'καί', 'οὐ', 'ὡς', 'ὁ',
#        'γραμματεύς', 'καί', 'εὐθύς', 'εἰμί', 'ἐν', 'ὁ', 'συναγωγή',
#        'αὐτός', 'ἄνθρωπος', 'ἐν', 'πνεῦμα', 'ἀκάθαρτος', 'καί',
#        'ἀνακράζω', 'λέγω', 'τίς', 'ἐγώ', 'καί', 'σύ', 'Ἰησοῦς',
#        'Ναζαρηνός', 'ἔρχομαι', 'ἀπόλλυμι', 'ἐγώ', 'οἶδα', 'σύ', 'τίς',
#        'εἰμί', 'ὁ', 'ἅγιος', 'ὁ', 'θεός', 'καί', 'ἐπιτιμάω', 'αὐτός', 'ὁ',
#        'Ἰησοῦς', 'λέγω', 'φιμόω', 'καί', 'ἐξέρχομαι', 'ἐκ', 'αὐτός',
#        'καί', 'σπαράσσω', 'αὐτός', 'ὁ', 'πνεῦμα', 'ὁ', 'ἀκάθαρτος', 'καί',
#        'φωνέω', 'φωνή', 'μέγας', 'ἐξέρχομαι', 'ἐκ', 'αὐτός', 'καί',
#        'θαμβέομαι', 'ἅπας', 'ὥστε', 'συζητέω', 'πρός', 'ἑαυτοῦ', 'λέγω',
#        'τίς', 'εἰμί', 'οὗτος', 'διδαχή', 'καινός', 'κατά', 'ἐξουσία',
#        'καί', 'ὁ', 'πνεῦμα', 'ὁ', 'ἀκάθαρτος', 'ἐπιτάσσω', 'καί',
#        'ὑπακούω', 'αὐτός', 'καί', 'ἐξέρχομαι', 'ὁ', 'ἀκοή', 'αὐτός',
#        'εὐθύς', 'πανταχοῦ', 'εἰς', 'ὅλος', 'ὁ', 'περίχωρος', 'ὁ',
#        'Γαλιλαία', 'καί', 'εὐθύς', 'ἐκ', 'ὁ', 'συναγωγή', 'ἐξέρχομαι',
#        'ἔρχομαι', 'εἰς', 'ὁ', 'οἰκία', 'Σίμων', 'καί', 'Ἀνδρέας', 'μετά',
#        'Ἰάκωβος', 'καί', 'Ἰωάννης', 'ὁ', 'δέ', 'πενθερά', 'Σίμων',
#        'κατάκειμαι', 'πυρέσσω', 'καί', 'εὐθύς', 'λέγω', 'αὐτός', 'περί',
#        'αὐτός', 'καί', 'προσέρχομαι', 'ἐγείρω', 'αὐτός', 'κρατέω', 'ὁ',
#        'χείρ', 'καί', 'ἀφίημι', 'αὐτός', 'ὁ', 'πυρετός', 'καί',
#        'διακονέω', 'αὐτός', 'ὀψία', 'δέ', 'γίνομαι', 'ὅτε', 'δύνω', 'ὁ',
#        'ἥλιος', 'φέρω', 'πρός', 'αὐτός', 'πᾶς', 'ὁ', 'κακῶς', 'ἔχω',
#        'καί', 'ὁ', 'δαιμονίζομαι', 'καί', 'εἰμί', 'ὅλος', 'ὁ', 'πόλις',
#        'ἐπισυνάγω', 'πρός', 'ὁ', 'θύρα', 'καί', 'θεραπεύω', 'πολύς',
#        'κακῶς', 'ἔχω', 'ποικίλος', 'νόσος', 'καί', 'δαιμόνιον', 'πολύς',
#        'ἐκβάλλω', 'καί', 'οὐ', 'ἀφίημι', 'λαλέω', 'ὁ', 'δαιμόνιον', 'ὅτι',
#        'οἶδα', 'αὐτός', 'καί', 'πρωΐ', 'ἔννυχα', 'λίαν', 'ἀνίστημι',
#        'ἐξέρχομαι', 'καί', 'ἀπέρχομαι', 'εἰς', 'ἔρημος', 'τόπος', 'κἀκεῖ',
#        'προσεύχομαι', 'καί', 'καταδιώκω', 'αὐτός', 'Σίμων', 'καί', 'ὁ',
#        'μετά', 'αὐτός', 'καί', 'εὑρίσκω', 'αὐτός', 'καί', 'λέγω', 'αὐτός',
#        'ὅτι', 'πᾶς', 'ζητέω', 'σύ', 'καί', 'λέγω', 'αὐτός', 'ἄγω',
#        'ἀλλαχοῦ', 'εἰς', 'ὁ', 'ἔχω', 'κωμόπολις', 'ἵνα', 'καί', 'ἐκεῖ',
#        'κηρύσσω', 'εἰς', 'οὗτος', 'γάρ', 'ἐξέρχομαι', 'καί', 'ἔρχομαι',
#        'κηρύσσω', 'εἰς', 'ὁ', 'συναγωγή', 'αὐτός', 'εἰς', 'ὅλος', 'ὁ',
#        'Γαλιλαία', 'καί', 'ὁ', 'δαιμόνιον', 'ἐκβάλλω', 'καί', 'ἔρχομαι',
#        'πρός', 'αὐτός', 'λεπρός', 'παρακαλέω', 'αὐτός', 'καί',
#        'γονυπετέω', 'λέγω', 'αὐτός', 'ὅτι', 'ἐάν', 'θέλω', 'δύναμαι',
#        'ἐγώ', 'καθαρίζω', 'καί', 'ὀργίζομαι', 'ἐκτείνω', 'ὁ', 'χείρ',
#        'αὐτός', 'ἅπτω', 'καί', 'λέγω', 'αὐτός', 'θέλω', 'καθαρίζω', 'καί',
#        'εὐθύς', 'ἀπέρχομαι', 'ἀπό', 'αὐτός', 'ὁ', 'λέπρα', 'καί',
#        'καθαρίζω', 'καί', 'ἐμβριμάομαι', 'αὐτός', 'εὐθύς', 'ἐκβάλλω',
#        'αὐτός', 'καί', 'λέγω', 'αὐτός', 'ὁράω', 'μηδείς', 'μηδείς',
#        'λέγω', 'ἀλλά', 'ὑπάγω', 'σεαυτοῦ', 'δείκνυμι', 'ὁ', 'ἱερεύς',
#        'καί', 'προσφέρω', 'περί', 'ὁ', 'καθαρισμός', 'σύ', 'ὅς',
#        'προστάσσω', 'Μωϋσῆς', 'εἰς', 'μαρτύριον', 'αὐτός', 'ὁ', 'δέ',
#        'ἐξέρχομαι', 'ἄρχω', 'κηρύσσω', 'πολύς', 'καί', 'διαφημίζω', 'ὁ',
#        'λόγος', 'ὥστε', 'μηκέτι', 'αὐτός', 'δύναμαι', 'φανερῶς', 'εἰς',
#        'πόλις', 'εἰσέρχομαι', 'ἀλλά', 'ἔξω', 'ἐπί', 'ἔρημος', 'τόπος',
#        'εἰμί', 'καί', 'ἔρχομαι', 'πρός', 'αὐτός', 'πάντοθεν'],
#       dtype=object),
#  'level': None,
#  'obj': 18329          ἀρχή
# 18330             ὁ
# 18331    εὐαγγέλιον
# 18332        Ἰησοῦς
# 18333       Χριστός
#             ...
# 19025           καί
# 19026       ἔρχομαι
# 19027          πρός
# 19028         αὐτός
# 19029      πάντοθεν
# Name: Lemma, Length: 701, dtype: object,
#  'observed': False,
#  'sort': True}
# -----
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x00000204CA5C96D0>

# %% [markdown]
# ## Get Word Count for Each Lemma (S_LEMMA_VALUE_COUNTS)

# %%
S_LEMMA_VALUE_COUNTS = GB_LEMMA_VALUES.count()

print("===== S_LEMMA_VALUE_COUNTS")
print(S_LEMMA_VALUE_COUNTS.__class__.__name__)
print("-----")
pprint(vars(S_LEMMA_VALUE_COUNTS))
print("-----")
pprint(S_LEMMA_VALUE_COUNTS)
# Out:
# ===== S_LEMMA_VALUE_COUNTS
# Series
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': SingleBlockManager
# Items: Index(['Γαλιλαία', 'Ζεβεδαῖος', 'Καφαρναούμ', 'Μωϋσῆς', 'Ναζαρέτ', 'Ναζαρηνός',
#        'Σίμων', 'Σατανᾶς', 'Χριστός', 'αὐτός',
#        ...
#        'ὅς', 'ὅτε', 'ὅτι', 'ὑπάγω', 'ὑπακούω', 'ὑπό', 'ὑπόδημα', 'ὕδωρ', 'ὡς',
#        'ὥστε'],
#       dtype='object', length=239)
# NumpyBlock: 239 dtype: int64,
#  '_name': 'Lemma'}
# -----
# Γαλιλαία      5
# Ζεβεδαῖος     2
# Καφαρναούμ    1
# Μωϋσῆς        1
# Ναζαρέτ       1
#              ..
# ὑπό           3
# ὑπόδημα       1
# ὕδωρ          2
# ὡς            3
# ὥστε          2
# Name: Lemma, Length: 239, dtype: int64

# %% [markdown]
# ## Create DataFrame for Lemma Analysis (DF_ANALYSIS)

# %%
DF_ANALYSIS = S_LEMMA_VALUE_COUNTS.to_frame(name="Lemma Count")
DF_ANALYSIS.index.name = "Lemma"

print("===== DF_ANALYSIS")
print(DF_ANALYSIS.__class__.__name__)
print("-----")
pprint(vars(DF_ANALYSIS))
print("-----")
pprint(DF_ANALYSIS)
# Out:
# ===== DF_ANALYSIS
# DataFrame
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': BlockManager
# Items: Index(['Lemma Count'], dtype='object')
# Axis 1: Index(['Γαλιλαία', 'Ζεβεδαῖος', 'Καφαρναούμ', 'Μωϋσῆς', 'Ναζαρέτ', 'Ναζαρηνός',
#        'Σίμων', 'Σατανᾶς', 'Χριστός', 'αὐτός',
#        ...
#        'ὅς', 'ὅτε', 'ὅτι', 'ὑπάγω', 'ὑπακούω', 'ὑπό', 'ὑπόδημα', 'ὕδωρ', 'ὡς',
#        'ὥστε'],
#       dtype='object', name='Lemma', length=239)
# NumpyBlock: slice(0, 1, 1), 1 x 239, dtype: int64}
# -----
#             Lemma Count
# Lemma
# Γαλιλαία              5
# Ζεβεδαῖος             2
# Καφαρναούμ            1
# Μωϋσῆς                1
# Ναζαρέτ               1
# ...                 ...
# ὑπό                   3
# ὑπόδημα               1
# ὕδωρ                  2
# ὡς                    3
# ὥστε                  2
#
# [239 rows x 1 columns]

# %% [markdown]
# ## Add Word Percentage to Analysis (DF_ANALYSIS)

# %%
DF_ANALYSIS["Lemma Percentage"] = (DF_ANALYSIS["Lemma Count"] / TOTAL_WORD_COUNT) * 100

print("===== DF_ANALYSIS")
print(DF_ANALYSIS.__class__.__name__)
print("-----")
pprint(vars(DF_ANALYSIS))
print("-----")
pprint(DF_ANALYSIS)
# Out:
# ===== DF_ANALYSIS
# DataFrame
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {'Lemma Count': Lemma
# Γαλιλαία      5
# Ζεβεδαῖος     2
# Καφαρναούμ    1
# Μωϋσῆς        1
# Ναζαρέτ       1
#              ..
# ὑπό           3
# ὑπόδημα       1
# ὕδωρ          2
# ὡς            3
# ὥστε          2
# Name: Lemma Count, Length: 239, dtype: int64},
#  '_mgr': BlockManager
# Items: Index(['Lemma Count', 'Lemma Percentage'], dtype='object')
# Axis 1: Index(['Γαλιλαία', 'Ζεβεδαῖος', 'Καφαρναούμ', 'Μωϋσῆς', 'Ναζαρέτ', 'Ναζαρηνός',
#        'Σίμων', 'Σατανᾶς', 'Χριστός', 'αὐτός',
#        ...
#        'ὅς', 'ὅτε', 'ὅτι', 'ὑπάγω', 'ὑπακούω', 'ὑπό', 'ὑπόδημα', 'ὕδωρ', 'ὡς',
#        'ὥστε'],
#       dtype='object', name='Lemma', length=239)
# NumpyBlock: slice(0, 1, 1), 1 x 239, dtype: int64
# NumpyBlock: slice(1, 2, 1), 1 x 239, dtype: float64}
# -----
#             Lemma Count  Lemma Percentage
# Lemma
# Γαλιλαία              5          0.713267
# Ζεβεδαῖος             2          0.285307
# Καφαρναούμ            1          0.142653
# Μωϋσῆς                1          0.142653
# Ναζαρέτ               1          0.142653
# ...                 ...               ...
# ὑπό                   3          0.427960
# ὑπόδημα               1          0.142653
# ὕδωρ                  2          0.285307
# ὡς                    3          0.427960
# ὥστε                  2          0.285307
#
# [239 rows x 2 columns]

# %% [markdown]
# ## Add Cumulative Percentage Column (DF_ANALYSYS)

# %%
DF_ANALYSIS = DF_ANALYSIS.sort_values("Lemma Percentage", ascending=False)
DF_ANALYSIS["Word Index"] = range(len(DF_ANALYSIS))
DF_ANALYSIS["Lemma Percentage Cumulative"] = DF_ANALYSIS["Lemma Percentage"].cumsum()

DF_ANALYSIS = DF_ANALYSIS[DF_ANALYSIS["Word Index"] < 100]

print("===== DF_ANALYSIS")
print(DF_ANALYSIS.__class__.__name__)
print("-----")
pprint(vars(DF_ANALYSIS))
print("-----")
pprint(DF_ANALYSIS)
# Out:
# ===== DF_ANALYSIS
# DataFrame
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': <weakref at 0x00000204C45EFBA0; dead>,
#  '_item_cache': {},
#  '_mgr': BlockManager
# Items: Index(['Lemma Count', 'Lemma Percentage', 'Word Index',
#        'Lemma Percentage Cumulative'],
#       dtype='object')
# Axis 1: Index(['ὁ', 'καί', 'αὐτός', 'εἰς', 'ἐν', 'λέγω', 'εἰμί', 'εὐθύς', 'σύ', 'ἐγώ',
#        'ἔρχομαι', 'ἐξέρχομαι', 'ἔρημος', 'πνεῦμα', 'κηρύσσω', 'πρός', 'Ἰησοῦς',
#        'Ἰωάννης', 'βαπτίζω', 'γίνομαι', 'ἐκ', 'Σίμων', 'μετά', 'Γαλιλαία',
#        'πᾶς', 'ἐκβάλλω', 'ἀφίημι', 'συναγωγή', 'ὁράω', 'ἔχω', 'ὅτι', 'δέ',
#        'οὐ', 'καθαρίζω', 'δαιμόνιον', 'θεός', 'γάρ', 'περί', 'ἀκάθαρτος',
#        'τίς', 'φωνή', 'πολύς', 'ὀπίσω', 'ὅλος', 'ὑπό', 'ἀπέρχομαι',
#        'εὐαγγέλιον', 'ὅς', 'ὡς', 'ἀπό', 'ἀδελφός', 'ἀλλά', 'χείρ', 'οἶδα',
#        'μηδείς', 'δύναμαι', 'θέλω', 'θάλασσα', 'δίκτυον', 'διακονέω', 'διδαχή',
#        'Ζεβεδαῖος', 'διδάσκω', 'πόλις', 'τόπος', 'ἐξουσία', 'ὕδωρ', 'Ἰάκωβος',
#        'ὁδός', 'ὥστε', 'Ἰορδάνης', 'ἐπί', 'Ἀνδρέας', 'ἡμέρα', 'ἁμαρτία',
#        'ἁλιεύς', 'ἅγιος', 'ἄνθρωπος', 'ἄγγελος', 'οὐρανός', 'πλοῖον', 'ποιέω',
#        'κακῶς', 'οὗτος', 'δύνω', 'εἰσπορεύομαι', 'εὐδοκέω', 'εἰσέρχομαι',
#        'γονυπετέω', 'γράφω', 'γραμματεύς', 'δεῦτε', 'δερμάτινος', 'δείκνυμι',
#        'θύρα', 'θεραπεύω', 'θαμβέομαι', 'ζητέω', 'ζώνη', 'εὑρίσκω'],
#       dtype='object', name='Lemma')
# NumpyBlock: slice(0, 1, 1), 1 x 100, dtype: int64
# NumpyBlock: slice(1, 2, 1), 1 x 100, dtype: float64
# NumpyBlock: slice(2, 3, 1), 1 x 100, dtype: int64
# NumpyBlock: slice(3, 4, 1), 1 x 100, dtype: float64}
# -----
#            Lemma Count  Lemma Percentage  Word Index  \
# Lemma
# ὁ                   95         13.552068           0
# καί                 79         11.269615           1
# αὐτός               51          7.275321           2
# εἰς                 16          2.282454           3
# ἐν                  14          1.997147           4
# ...                ...               ...         ...
# θεραπεύω             1          0.142653          95
# θαμβέομαι            1          0.142653          96
# ζητέω                1          0.142653          97
# ζώνη                 1          0.142653          98
# εὑρίσκω              1          0.142653          99
#
#            Lemma Percentage Cumulative
# Lemma
# ὁ                            13.552068
# καί                          24.821683
# αὐτός                        32.097004
# εἰς                          34.379458
# ἐν                           36.376605
# ...                                ...
# θεραπεύω                     79.600571
# θαμβέομαι                    79.743224
# ζητέω                        79.885877
# ζώνη                         80.028531
# εὑρίσκω                      80.171184
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Merge Analysis with Lexemes (DF_MERGED)

# %%
DF_MERGED = DF_ANALYSIS.join(DF_LEXEMES)

print("===== DF_MERGED")
print(DF_MERGED.__class__.__name__)
print("-----")
pprint(vars(DF_MERGED))
print("-----")
pprint(DF_MERGED)
# Out:
# ===== DF_MERGED
# DataFrame
# -----
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': BlockManager
# Items: Index(['Lemma Count', 'Lemma Percentage', 'Word Index',
#        'Lemma Percentage Cumulative', 'pos', 'full-citation-form',
#        'bdag-headword', 'danker-entry', 'dodson-entry', 'mounce-headword',
#        'strongs', 'gk', 'dodson-pos', 'gloss', 'mounce-morphcat'],
#       dtype='object')
# Axis 1: Index(['ὁ', 'καί', 'αὐτός', 'εἰς', 'ἐν', 'λέγω', 'εἰμί', 'εὐθύς', 'σύ', 'ἐγώ',
#        'ἔρχομαι', 'ἐξέρχομαι', 'ἔρημος', 'πνεῦμα', 'κηρύσσω', 'πρός', 'Ἰησοῦς',
#        'Ἰωάννης', 'βαπτίζω', 'γίνομαι', 'ἐκ', 'Σίμων', 'μετά', 'Γαλιλαία',
#        'πᾶς', 'ἐκβάλλω', 'ἀφίημι', 'συναγωγή', 'ὁράω', 'ἔχω', 'ὅτι', 'δέ',
#        'οὐ', 'καθαρίζω', 'δαιμόνιον', 'θεός', 'γάρ', 'περί', 'ἀκάθαρτος',
#        'τίς', 'φωνή', 'πολύς', 'ὀπίσω', 'ὅλος', 'ὑπό', 'ἀπέρχομαι',
#        'εὐαγγέλιον', 'ὅς', 'ὡς', 'ἀπό', 'ἀδελφός', 'ἀλλά', 'χείρ', 'οἶδα',
#        'μηδείς', 'δύναμαι', 'θέλω', 'θάλασσα', 'δίκτυον', 'διακονέω', 'διδαχή',
#        'Ζεβεδαῖος', 'διδάσκω', 'πόλις', 'τόπος', 'ἐξουσία', 'ὕδωρ', 'Ἰάκωβος',
#        'ὁδός', 'ὥστε', 'Ἰορδάνης', 'ἐπί', 'Ἀνδρέας', 'ἡμέρα', 'ἁμαρτία',
#        'ἁλιεύς', 'ἅγιος', 'ἄνθρωπος', 'ἄγγελος', 'οὐρανός', 'πλοῖον', 'ποιέω',
#        'κακῶς', 'οὗτος', 'δύνω', 'εἰσπορεύομαι', 'εὐδοκέω', 'εἰσέρχομαι',
#        'γονυπετέω', 'γράφω', 'γραμματεύς', 'δεῦτε', 'δερμάτινος', 'δείκνυμι',
#        'θύρα', 'θεραπεύω', 'θαμβέομαι', 'ζητέω', 'ζώνη', 'εὑρίσκω'],
#       dtype='object', name='Lemma')
# NumpyBlock: slice(1, 5, 2), 2 x 100, dtype: float64
# NumpyBlock: slice(0, 4, 2), 2 x 100, dtype: int64
# NumpyBlock: slice(4, 15, 1), 11 x 100, dtype: object}
# -----
#            Lemma Count  Lemma Percentage  Word Index  \
# Lemma
# ὁ                   95         13.552068           0
# καί                 79         11.269615           1
# αὐτός               51          7.275321           2
# εἰς                 16          2.282454           3
# ἐν                  14          1.997147           4
# ...                ...               ...         ...
# θεραπεύω             1          0.142653          95
# θαμβέομαι            1          0.142653          96
# ζητέω                1          0.142653          97
# ζώνη                 1          0.142653          98
# εὑρίσκω              1          0.142653          99
#
#            Lemma Percentage Cumulative pos full-citation-form bdag-headword  \
# Lemma
# ὁ                            13.552068  RA                NaN             ὁ
# καί                          24.821683   C                NaN           καί
# αὐτός                        32.097004  RP                NaN         αὐτός
# εἰς                          34.379458   P                NaN           εἰς
# ἐν                           36.376605   P                NaN            ἐν
# ...                                ...  ..                ...           ...
# θεραπεύω                     79.600571   V                NaN      θεραπεύω
# θαμβέομαι                    79.743224   V                NaN        θαμβέω
# ζητέω                        79.885877   V                NaN         ζητέω
# ζώνη                         80.028531   N        ζώνη, ης, ἡ          ζώνη
# εὑρίσκω                      80.171184   V                NaN       εὑρίσκω
#
#                        danker-entry       dodson-entry mounce-headword  \
# Lemma
# ὁ          ὁ, ἡ, τό; pl. οἱ, αἱ, τά           ὁ, ἡ, τό               ὁ
# καί                             καί                καί             καί
# αὐτός             αὐτός, αὐτή, αὐτό  αὐτός, αὐτή, αὐτό           αὐτός
# εἰς                             εἰς                εἰς             εἰς
# ἐν                               ἐν                 ἐν              ἐν
# ...                             ...                ...             ...
# θεραπεύω                   θεραπεύω           θεραπεύω        θεραπεύω
# θαμβέομαι                    θαμβέω             θαμβέω          θαμβέω
# ζητέω                         ζητέω              ζητέω           ζητέω
# ζώνη                    ζώνη, ης, ἡ        ζώνη, ῆς, ἡ            ζώνη
# εὑρίσκω                     εὑρίσκω            εὑρίσκω         εὑρίσκω
#
#           strongs    gk dodson-pos                            gloss  \
# Lemma
# ὁ            3588  3836          T                              the
# καί          2532  2779       CONJ          and, even, also, namely
# αὐτός         846   899          P    he, she, it, they, them, same
# εἰς          1519  1650       PREP       into, in, among, till, for
# ἐν           1722  1877       PREP                    in, on, among
# ...           ...   ...        ...                              ...
# θεραπεύω     2323  2543          V  I care for, attend, serve, heal
# θαμβέομαι    2284  2501          V                          I amaze
# ζητέω        2212  2426          V       I seek, search for, desire
# ζώνη         2223  2438        N:F            a girdle, belt, purse
# εὑρίσκω      2147  2351          V                           I find
#
#           mounce-morphcat
# Lemma
# ὁ                a-1a(2b)
# καί                  conj
# αὐτός            a-1a(2b)
# εἰς                  prep
# ἐν                   prep
# ...                   ...
# θεραπεύω          v-1a(6)
# θαμβέομαι        v-1d(2a)
# ζητέω            v-1d(2a)
# ζώνη                 n-1b
# εὑρίσκω              v-5b
#
# [100 rows x 15 columns]

# %% [markdown]
# ## Display Word Analysis

# %%
DF_MERGED_REORDERED=DF_MERGED.reindex(columns=['Word Index','bdag-headword','dodson-entry','pos','gloss','strongs','gk','Lemma Count','Lemma Percentage','Lemma Percentage Cumulative'])
DF_MERGED_REORDERED.style.hide(axis="index").set_properties(
    subset=["gloss", "bdag-headword","dodson-entry", "pos"], **{"text-align": "left"}
).set_table_styles([
    {'selector': 'th', 'props': [('text-align', 'left')]}
]).bar(
    subset=["Lemma Percentage Cumulative"], vmax=100
)
# Out:
# <style type="text/css">
# #T_bf8cc th {
#   text-align: left;
# }
# #T_bf8cc_row0_col1, #T_bf8cc_row0_col2, #T_bf8cc_row0_col3, #T_bf8cc_row0_col4, #T_bf8cc_row1_col1, #T_bf8cc_row1_col2, #T_bf8cc_row1_col3, #T_bf8cc_row1_col4, #T_bf8cc_row2_col1, #T_bf8cc_row2_col2, #T_bf8cc_row2_col3, #T_bf8cc_row2_col4, #T_bf8cc_row3_col1, #T_bf8cc_row3_col2, #T_bf8cc_row3_col3, #T_bf8cc_row3_col4, #T_bf8cc_row4_col1, #T_bf8cc_row4_col2, #T_bf8cc_row4_col3, #T_bf8cc_row4_col4, #T_bf8cc_row5_col1, #T_bf8cc_row5_col2, #T_bf8cc_row5_col3, #T_bf8cc_row5_col4, #T_bf8cc_row6_col1, #T_bf8cc_row6_col2, #T_bf8cc_row6_col3, #T_bf8cc_row6_col4, #T_bf8cc_row7_col1, #T_bf8cc_row7_col2, #T_bf8cc_row7_col3, #T_bf8cc_row7_col4, #T_bf8cc_row8_col1, #T_bf8cc_row8_col2, #T_bf8cc_row8_col3, #T_bf8cc_row8_col4, #T_bf8cc_row9_col1, #T_bf8cc_row9_col2, #T_bf8cc_row9_col3, #T_bf8cc_row9_col4, #T_bf8cc_row10_col1, #T_bf8cc_row10_col2, #T_bf8cc_row10_col3, #T_bf8cc_row10_col4, #T_bf8cc_row11_col1, #T_bf8cc_row11_col2, #T_bf8cc_row11_col3, #T_bf8cc_row11_col4, #T_bf8cc_row12_col1, #T_bf8cc_row12_col2, #T_bf8cc_row12_col3, #T_bf8cc_row12_col4, #T_bf8cc_row13_col1, #T_bf8cc_row13_col2, #T_bf8cc_row13_col3, #T_bf8cc_row13_col4, #T_bf8cc_row14_col1, #T_bf8cc_row14_col2, #T_bf8cc_row14_col3, #T_bf8cc_row14_col4, #T_bf8cc_row15_col1, #T_bf8cc_row15_col2, #T_bf8cc_row15_col3, #T_bf8cc_row15_col4, #T_bf8cc_row16_col1, #T_bf8cc_row16_col2, #T_bf8cc_row16_col3, #T_bf8cc_row16_col4, #T_bf8cc_row17_col1, #T_bf8cc_row17_col2, #T_bf8cc_row17_col3, #T_bf8cc_row17_col4, #T_bf8cc_row18_col1, #T_bf8cc_row18_col2, #T_bf8cc_row18_col3, #T_bf8cc_row18_col4, #T_bf8cc_row19_col1, #T_bf8cc_row19_col2, #T_bf8cc_row19_col3, #T_bf8cc_row19_col4, #T_bf8cc_row20_col1, #T_bf8cc_row20_col2, #T_bf8cc_row20_col3, #T_bf8cc_row20_col4, #T_bf8cc_row21_col1, #T_bf8cc_row21_col2, #T_bf8cc_row21_col3, #T_bf8cc_row21_col4, #T_bf8cc_row22_col1, #T_bf8cc_row22_col2, #T_bf8cc_row22_col3, #T_bf8cc_row22_col4, #T_bf8cc_row23_col1, #T_bf8cc_row23_col2, #T_bf8cc_row23_col3, #T_bf8cc_row23_col4, #T_bf8cc_row24_col1, #T_bf8cc_row24_col2, #T_bf8cc_row24_col3, #T_bf8cc_row24_col4, #T_bf8cc_row25_col1, #T_bf8cc_row25_col2, #T_bf8cc_row25_col3, #T_bf8cc_row25_col4, #T_bf8cc_row26_col1, #T_bf8cc_row26_col2, #T_bf8cc_row26_col3, #T_bf8cc_row26_col4, #T_bf8cc_row27_col1, #T_bf8cc_row27_col2, #T_bf8cc_row27_col3, #T_bf8cc_row27_col4, #T_bf8cc_row28_col1, #T_bf8cc_row28_col2, #T_bf8cc_row28_col3, #T_bf8cc_row28_col4, #T_bf8cc_row29_col1, #T_bf8cc_row29_col2, #T_bf8cc_row29_col3, #T_bf8cc_row29_col4, #T_bf8cc_row30_col1, #T_bf8cc_row30_col2, #T_bf8cc_row30_col3, #T_bf8cc_row30_col4, #T_bf8cc_row31_col1, #T_bf8cc_row31_col2, #T_bf8cc_row31_col3, #T_bf8cc_row31_col4, #T_bf8cc_row32_col1, #T_bf8cc_row32_col2, #T_bf8cc_row32_col3, #T_bf8cc_row32_col4, #T_bf8cc_row33_col1, #T_bf8cc_row33_col2, #T_bf8cc_row33_col3, #T_bf8cc_row33_col4, #T_bf8cc_row34_col1, #T_bf8cc_row34_col2, #T_bf8cc_row34_col3, #T_bf8cc_row34_col4, #T_bf8cc_row35_col1, #T_bf8cc_row35_col2, #T_bf8cc_row35_col3, #T_bf8cc_row35_col4, #T_bf8cc_row36_col1, #T_bf8cc_row36_col2, #T_bf8cc_row36_col3, #T_bf8cc_row36_col4, #T_bf8cc_row37_col1, #T_bf8cc_row37_col2, #T_bf8cc_row37_col3, #T_bf8cc_row37_col4, #T_bf8cc_row38_col1, #T_bf8cc_row38_col2, #T_bf8cc_row38_col3, #T_bf8cc_row38_col4, #T_bf8cc_row39_col1, #T_bf8cc_row39_col2, #T_bf8cc_row39_col3, #T_bf8cc_row39_col4, #T_bf8cc_row40_col1, #T_bf8cc_row40_col2, #T_bf8cc_row40_col3, #T_bf8cc_row40_col4, #T_bf8cc_row41_col1, #T_bf8cc_row41_col2, #T_bf8cc_row41_col3, #T_bf8cc_row41_col4, #T_bf8cc_row42_col1, #T_bf8cc_row42_col2, #T_bf8cc_row42_col3, #T_bf8cc_row42_col4, #T_bf8cc_row43_col1, #T_bf8cc_row43_col2, #T_bf8cc_row43_col3, #T_bf8cc_row43_col4, #T_bf8cc_row44_col1, #T_bf8cc_row44_col2, #T_bf8cc_row44_col3, #T_bf8cc_row44_col4, #T_bf8cc_row45_col1, #T_bf8cc_row45_col2, #T_bf8cc_row45_col3, #T_bf8cc_row45_col4, #T_bf8cc_row46_col1, #T_bf8cc_row46_col2, #T_bf8cc_row46_col3, #T_bf8cc_row46_col4, #T_bf8cc_row47_col1, #T_bf8cc_row47_col2, #T_bf8cc_row47_col3, #T_bf8cc_row47_col4, #T_bf8cc ...
